# %%
import pandas as pd
import numpy as np

import re

from utils import tag_mail

# %%
df = pd.read_json(r'data/gmail_turc_send.txt', encoding = 'utf-8')

# %%
df['cat'] = df.headers.apply(tag_mail)

# %%
def clean_and_tokenize(text):
    """
    Cleaning a document with:
        - Lowercase        
        - Removing numbers with regular expressions
        - Removing punctuation with regular expressions
        - Removing other artifacts
    And separate the document into words by simply splitting at spaces
    Params:
        text (string): a sentence or a document
    Returns:
        tokens (list of strings): the list of tokens (word units) forming the document
    """        
    # Lowercase
    text = text.lower()
    # Remove numbers
    text = re.sub(r"[0-9]+", "", text)
    # Remove punctuation
    REMOVE_PUNCT = re.compile("[.;:!\'?,\"()\[\]]")
    text = REMOVE_PUNCT.sub("", text)
    # Remove small words (1 and 2 characters)
    text = re.sub(r"\b\w{1,2}\b", "", text)
    # Remove HTML artifacts specific to the corpus we're going to work with
    REPLACE_HTML = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)")
    text = REPLACE_HTML.sub(" ", text)
    
    tokens = text.split()
    return tokens

# %%
df['clean_text_tok'] = df.body.apply(clean_and_tokenize)

# %%
categories = ['sport','education', 'alimentation']
vocab = []
vocab_concept = []

for cat in categories:
    with open('vocabulary/final/'+cat+'_all.txt', 'r') as f:
        v = f.read().split('\n')
        while("" in v) : 
            v.remove("") 
        vocab +=  v
    with open('vocabulary/final/'+cat+'_concept.txt', 'r') as f:
        v = f.read().split('\n')
        while("" in v) : 
            v.remove("")
        vocab += v
        vocab_concept.append(v)

# %%
def lookup(list):
    count = 0
    for x in list:
        if x in vocab:
            count += 1
    return count

# %%
def see_words(text):
    L = []
    for el in text:
        if el in vocab:
            L+=[el]
    return L

# %%
df['words'] = df['clean_text_tok'].apply(see_words)
df['count'] = df['clean_text_tok'].apply(lookup)

# %%
def addToFound(words_found, words):
    for w in words:
        if w in words_found:
            words_found[w] += 1
        else:
            words_found[w] = 1
    return words_found

# %%
def getExtractedWords(bow):
    last = bow[0]
    words_found = addToFound({}, last)
    for i in range(1, len(bow)):
        new = False
        for j in range(len(bow[i])):
            if bow[i][j] not in last:
                new = True
                break
        if new:
            last = bow[i]
            words_found = addToFound(words_found, last)
    return words_found

# %%
words = getExtractedWords(df.loc[df['count']>0].words.values.tolist())
print(len(words))
for w in words:
    print(w, words[w])
# Out:
# {'stage': 8}
# 22
# formation 2
# manger 6
# famine 2
# admission 1
# club 2
# restaurant 2
# sport 12
# polytechnique 4
# alimentaire 2
# champion 1
# karting 2
# piscine 1
# connaissance 7
# science 16
# recherche 6
# volleyball 2
# noix 10
# scolaire 2
# stage 42
# basket 4
# sportive 4
# football 2

# %%
for el in df.loc[df['count']>0].body:
    print(el)
    print('\n\n\n\n')
# Out:
#    Bonjour Alexis,
#
# Bonne année et meilleur vœux pour 2020 !
#
# J'ai reçu des retours de mon école.
# Pour éditer la convention de stage, elle a besoin de quelques
# renseignements supplémentaires:
# - Le signataire de la convention de stage (nom, prénom, fonction, adresse
# mail)
# - Un contact RH (nom, prénom, fonction, adresse mail)
# - Un maître de stage (nom, prénom, fonction, adresse mail). Pour l'instant,
# j'avais supposé que c'était toi mais si ce n'est pas le cas, corrige moi.
# - Un descriptif du stage
#
# Ensuite concernant le PC, est-ce que c'est possible de faire un dual boot
# Windows/Linux, ou bien c'est forcément une VM intégrée à Windows ?
#
# Bien à toi,
#
# TURC Etienne
#
# Le ven. 13 déc. 2019 à 15:24, Alexis Deudon <alexis.deudon@paylead.fr> a
# écrit :
#
# > Le nouveau framework releasé par Netflix cette semaine (en attendant je
# > galère tjs autant à trouver un bon film mais bon..)
# >
# > Ce genre de trucs il en sort tous les mois j’ai l’impression
# >
# >
# >
# >
# >
# > Et peut-être un peu plus utile pour nous un jour (depuis ton premier
# > entretien on a fait environ X10 sur le nombre de transactions reçues chaque
# > jour…)
# >
# >
# >
# >
# >
# > Sinon le tour de table de notre Serie A est maintenant clôturé, on
# > officialise tout ça en janvier
# >
# >
# >
# > Et on a largement le temps mais n’hésite pas à me dire si tu es plutôt MAC
# > ou PC (VM linux sur dans un windows)
# >
# >
# >
# > Bon we ! (et toute l’équipe est vraiment contente de ton choix)
# >
# >
# >
# > *Alexis Deudon*
# > Chief Data Officer
# >
# > + 33 (0)6 03 02 00 92
# > Twitter < | LinkedIn
# > <
# >
# > [image: PayLead - Knowledge to inspire the right purchase]
# > <
# >
# > 55 rue la Boétie - 75008 Paris
# >
# >
# >
#  Bonjour Alexis,
# Bonne année et meilleur vœux pour 2020 !
# J'ai reçu des retours de mon école.Pour éditer la convention de stage, elle a besoin de quelques renseignements supplémentaires:- Le signataire de la convention de stage (nom, prénom, fonction, adresse mail)- Un contact RH (nom, prénom, fonction, adresse mail)- Un maître de stage (nom, prénom, fonction, adresse mail). Pour l'instant, j'avais supposé que c'était toi mais si ce n'est pas le cas, corrige moi.- Un descriptif du stage
# Ensuite concernant le PC, est-ce que c'est possible de faire un dual boot Windows/Linux, ou bien c'est forcément une VM intégrée à Windows ?
# Bien à toi,
# TURC Etienne
# Le ven. 13 déc. 2019 à 15:24, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Le nouveau framework releasé par Netflix cette semaine (en attendant je galère tjs autant à trouver un bon film mais bon..)
#
# Ce genre de trucs il en sort tous les mois j’ai l’impression
#
#
#
#
#
# Et peut-être un peu plus utile pour nous un jour (depuis ton premier entretien on a fait environ X10 sur le nombre de transactions reçues chaque jour…)
#
#
#
#
#
# Sinon le tour de table de notre Serie A est maintenant clôturé, on officialise tout ça en janvier
#
#
#
# Et on a largement le temps mais n’hésite pas à me dire si tu es plutôt MAC ou PC (VM linux sur dans un windows)
#
#
#
# Bon we ! (et toute l’équipe est vraiment contente de ton choix)
#
#
#
# Alexis Deudon
# Chief Data Officer
#
# + 33 (0)6 03 02 00 92
# Twitter|LinkedIn
#
#
#
# 55 rue la Boétie - 75008 Paris
#
#
#
#
#
#   Oui parfait,
# Mon numéro de téléphone est: +33602375632
#
# Le dim. 17 nov. 2019 à 11:19, Charles de Gastines <
# charles.degastines@paylead.fr> a écrit :
#
# > Avec plaisir.
# > Mardi à 18h ?
# > ++
# > Charles
# >
# > Le sam. 16 nov. 2019 à 20:07, etienne Turc <etienne.turc@gmail.com> a
# > écrit :
# >
# >> Bonsoir Charles,
# >>
# >> Merci. Je serais également ravi que tu puisses me parler de votre vision
# >> et stratégie.
# >> Est-tu disponible la semaine prochaine ?
# >>
# >> Bien à toi,
# >>
# >> Turc Etienne
# >>
# >> Le ven. 15 nov. 2019 à 19:11, Charles de Gastines <
# >> charles.degastines@paylead.fr> a écrit :
# >>
# >>> Bonsoir Etienne,
# >>>
# >>> Je te confirme que nous serions en effet ravi de t'avoir à nos côtés
# >>> dans notre aventures.
# >>> Si cela t'intéresse je serais ravi de te parler de notre vision et de
# >>> notre stratégie sur ce passionnant marché en ébullition !
# >>>
# >>> À ta disposition,
# >>>
# >>> Bon WE
# >>> ++
# >>>
# >>> Charles
# >>>
# >>>
# >>>
# >>> Le ven. 15 nov. 2019 à 12:28, Alexis Deudon <alexis.deudon@paylead.fr>
# >>> a écrit :
# >>>
# >>>> Hello Etienne,
# >>>>
# >>>>
# >>>>
# >>>> Comme discuté au téléphone, nous serions très heureux de te compter
# >>>> parmi nous à partir d’avril.
# >>>>
# >>>> Ton profil mi data / mi tech serait hyper complémentaire avec le reste
# >>>> de l’équipe et ce stage, s’il est réussi, pourrait naturellement déboucher
# >>>> sur une embauche.
# >>>>
# >>>>
# >>>>
# >>>> Rejoindre Paylead aujourd’hui c’est :
# >>>>
# >>>> - Rejoindre une boîte en pleine croissance sur un créneau porteur
# >>>> (tu as pu noter que Google venait de rentrer dans la danse…)
# >>>> - Bosser avec des experts Python / Infra / ML qui te feront
# >>>> progresser à vitesse grand V !
# >>>> - (pour la data) des « data mentoring » mensuels à Etienne De
# >>>> Rocquigny, ancien directeur du centre de recherche de Centrale Paris
# >>>> - Pouvoir choisir entre un MAC et un PC (VM Linux)
# >>>> - Des Paylead Bars tous les mois
# >>>> - Du café et des snacks à disposition
# >>>> - Profiter de notre politique « remote friendly »
# >>>> - Des tickets restos via la carte Lunchr
# >>>> - Etc.
# >>>>
# >>>>
# >>>>
# >>>> Je joins à cet email notre promesse d’embauche.
# >>>>
# >>>> J’inclus également Charles notre CEO dans cet email, je te propose
# >>>> qu’il te partage dans un meeting à venir sa vision du marché, de Paylead,
# >>>> de l’équipe data et son énergie !
# >>>>
# >>>>
# >>>>
# >>>> Je reste évidemment dispo pour toute question
# >>>>
# >>>>
# >>>>
# >>>> A bientôt !
# >>>>
# >>>>
# >>>>
# >>>> alexis
# >>>>
# >>>>
# >>>>
# >>>> NB : pour conclure une petite énigme qu’on m’a posée cette semaine.
# >>>> Combien de personnes faut-il dans une salle pour que la probabilité que 2
# >>>> d’entre elles ait le même anniversaire soit supérieure à 50% ?
# >>>>
# >>>>
# >>>>
# >>>>
# >>>>
# >>>
# >>>
# >>> --
# >>> --
# >>>
# >>> *Charles de Gastines*
# >>> CEO - Co-founder
# >>> + 33 (0) 6 80 16 27 82
# >>> Twitter
# >>> <
# >>> | LinkedIn
# >>> <
# >>>
# >>> [image: PayLead - Knowledge to inspire the right purchase]
# >>> < marketing budget into purchasing power*
# >>> 69 rue d'hauteville 75010 Paris
# >>>
# >>>
# >
# > --
# > --
# >
# > *Charles de Gastines*
# > CEO - Co-founder
# > + 33 (0) 6 80 16 27 82
# > Twitter
# > <
# > | LinkedIn
# > <
# >
# > [image: PayLead - Knowledge to inspire the right purchase]
# > < marketing budget into purchasing power*
# > 69 rue d'hauteville 75010 Paris
# >
# >
#  Oui parfait,Mon numéro de téléphone est: +33602375632
# Le dim. 17 nov. 2019 à 11:19, Charles de Gastines <charles.degastines@paylead.fr> a écrit :
# > Avec plaisir.Mardi à 18h ?++
# Charles
# Le sam. 16 nov. 2019 à 20:07, etienne Turc <etienne.turc@gmail.com> a écrit :
# > Bonsoir Charles,
# Merci. Je serais également ravi que tu puisses me parler de votre vision et stratégie.Est-tu disponible la semaine prochaine ?
# Bien à toi,
# Turc Etienne
# Le ven. 15 nov. 2019 à 19:11, Charles de Gastines <charles.degastines@paylead.fr> a écrit :
# > Bonsoir Etienne,
# Je te confirme que nous serions en effet ravi de t'avoir à nos côtés dans notre aventures.Si cela t'intéresse je serais ravi de te parler de notre vision et de notre stratégie sur ce passionnant marché en ébullition !
# À ta disposition,
# Bon WE++
#
# Charles
#
#
# Le ven. 15 nov. 2019 à 12:28, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Hello Etienne,
#
#
#
# Comme discuté au téléphone, nous serions très heureux de te compter parmi nous à partir d’avril.
#
# Ton profil mi data / mi tech serait hyper complémentaire avec le reste de l’équipe et ce stage, s’il est réussi, pourrait naturellement déboucher sur une embauche.
#
#
#
# Rejoindre Paylead aujourd’hui c’est :
#
#  * Rejoindre une boîte en pleine croissance sur un créneau porteur (tu as pu noter que Google venait de rentrer dans la danse…)
#  * Bosser avec des experts Python / Infra / ML qui te feront progresser à vitesse grand V !
#  * (pour la data) des « data mentoring » mensuels à Etienne De Rocquigny, ancien directeur du centre de recherche de Centrale Paris
#  * Pouvoir choisir entre un MAC et un PC (VM Linux)
#  * Des Paylead Bars tous les mois
#  * Du café et des snacks à disposition
#  * Profiter de notre politique « remote friendly »
#  * Des tickets restos via la carte Lunchr
#  * Etc.
#
#
#
# Je joins à cet email notre promesse d’embauche.
#
# J’inclus également Charles notre CEO dans cet email, je te propose qu’il te partage dans un meeting à venir sa vision du marché, de Paylead, de l’équipe data et son énergie !
#
#
#
# Je reste évidemment dispo pour toute question
#
#
#
# A bientôt !
#
#
#
# alexis
#
#
#
# NB : pour conclure une petite énigme qu’on m’a posée cette semaine. Combien de personnes faut-il dans une salle pour que la probabilité que 2 d’entre elles ait le même anniversaire soit supérieure à 50% ?
#
#
#
#
#
#
#
#
# --
# --
#
# Charles de Gastines
# CEO - Co-founder
# + 33 (0) 6 80 16 27 82
# Twitter|LinkedIn
#
# Turning marketing budget into purchasing power
# 69 rue d'hauteville 75010 Paris
#
#
#
#
#
# --
# --
#
# Charles de Gastines
# CEO - Co-founder
# + 33 (0) 6 80 16 27 82
# Twitter|LinkedIn
#
# Turning marketing budget into purchasing power
# 69 rue d'hauteville 75010 Paris
#
#
#
#
#
#   Bonsoir Alexis,
#
# Merci pour ton retour. Je vais regarder et évaluer tout cela à tête
# reposée.
# Je te tiens au courant :)
#
# NB: Il me semble que c'est 23 personnes.
#
# Bien à toi,
#
# Turc Etienne
#
# Le ven. 15 nov. 2019 à 12:28, Alexis Deudon <alexis.deudon@paylead.fr> a
# écrit :
#
# > Hello Etienne,
# >
# >
# >
# > Comme discuté au téléphone, nous serions très heureux de te compter parmi
# > nous à partir d’avril.
# >
# > Ton profil mi data / mi tech serait hyper complémentaire avec le reste de
# > l’équipe et ce stage, s’il est réussi, pourrait naturellement déboucher sur
# > une embauche.
# >
# >
# >
# > Rejoindre Paylead aujourd’hui c’est :
# >
# > - Rejoindre une boîte en pleine croissance sur un créneau porteur (tu
# > as pu noter que Google venait de rentrer dans la danse…)
# > - Bosser avec des experts Python / Infra / ML qui te feront progresser
# > à vitesse grand V !
# > - (pour la data) des « data mentoring » mensuels à Etienne De
# > Rocquigny, ancien directeur du centre de recherche de Centrale Paris
# > - Pouvoir choisir entre un MAC et un PC (VM Linux)
# > - Des Paylead Bars tous les mois
# > - Du café et des snacks à disposition
# > - Profiter de notre politique « remote friendly »
# > - Des tickets restos via la carte Lunchr
# > - Etc.
# >
# >
# >
# > Je joins à cet email notre promesse d’embauche.
# >
# > J’inclus également Charles notre CEO dans cet email, je te propose qu’il
# > te partage dans un meeting à venir sa vision du marché, de Paylead, de
# > l’équipe data et son énergie !
# >
# >
# >
# > Je reste évidemment dispo pour toute question
# >
# >
# >
# > A bientôt !
# >
# >
# >
# > alexis
# >
# >
# >
# > NB : pour conclure une petite énigme qu’on m’a posée cette semaine.
# > Combien de personnes faut-il dans une salle pour que la probabilité que 2
# > d’entre elles ait le même anniversaire soit supérieure à 50% ?
# >
# >
# >
# >
# >
#  Bonsoir Alexis,
# Merci pour ton retour. Je vais regarder et évaluer tout cela à tête reposée.Je te tiens au courant :)
# NB: Il me semble que c'est 23 personnes.
# Bien à toi,
# Turc Etienne
# Le ven. 15 nov. 2019 à 12:28, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Hello Etienne,
#
#
#
# Comme discuté au téléphone, nous serions très heureux de te compter parmi nous à partir d’avril.
#
# Ton profil mi data / mi tech serait hyper complémentaire avec le reste de l’équipe et ce stage, s’il est réussi, pourrait naturellement déboucher sur une embauche.
#
#
#
# Rejoindre Paylead aujourd’hui c’est :
#
#  * Rejoindre une boîte en pleine croissance sur un créneau porteur (tu as pu noter que Google venait de rentrer dans la danse…)
#  * Bosser avec des experts Python / Infra / ML qui te feront progresser à vitesse grand V !
#  * (pour la data) des « data mentoring » mensuels à Etienne De Rocquigny, ancien directeur du centre de recherche de Centrale Paris
#  * Pouvoir choisir entre un MAC et un PC (VM Linux)
#  * Des Paylead Bars tous les mois
#  * Du café et des snacks à disposition
#  * Profiter de notre politique « remote friendly »
#  * Des tickets restos via la carte Lunchr
#  * Etc.
#
#
#
# Je joins à cet email notre promesse d’embauche.
#
# J’inclus également Charles notre CEO dans cet email, je te propose qu’il te partage dans un meeting à venir sa vision du marché, de Paylead, de l’équipe data et son énergie !
#
#
#
# Je reste évidemment dispo pour toute question
#
#
#
# A bientôt !
#
#
#
# alexis
#
#
#
# NB : pour conclure une petite énigme qu’on m’a posée cette semaine. Combien de personnes faut-il dans une salle pour que la probabilité que 2 d’entre elles ait le même anniversaire soit supérieure à 50% ?
#
#
#
#
#
#   Bonsoir Charles,
#
# Merci. Je serais également ravi que tu puisses me parler de votre vision et
# stratégie.
# Est-tu disponible la semaine prochaine ?
#
# Bien à toi,
#
# Turc Etienne
#
# Le ven. 15 nov. 2019 à 19:11, Charles de Gastines <
# charles.degastines@paylead.fr> a écrit :
#
# > Bonsoir Etienne,
# >
# > Je te confirme que nous serions en effet ravi de t'avoir à nos côtés dans
# > notre aventures.
# > Si cela t'intéresse je serais ravi de te parler de notre vision et de
# > notre stratégie sur ce passionnant marché en ébullition !
# >
# > À ta disposition,
# >
# > Bon WE
# > ++
# >
# > Charles
# >
# >
# >
# > Le ven. 15 nov. 2019 à 12:28, Alexis Deudon <alexis.deudon@paylead.fr> a
# > écrit :
# >
# >> Hello Etienne,
# >>
# >>
# >>
# >> Comme discuté au téléphone, nous serions très heureux de te compter parmi
# >> nous à partir d’avril.
# >>
# >> Ton profil mi data / mi tech serait hyper complémentaire avec le reste de
# >> l’équipe et ce stage, s’il est réussi, pourrait naturellement déboucher sur
# >> une embauche.
# >>
# >>
# >>
# >> Rejoindre Paylead aujourd’hui c’est :
# >>
# >> - Rejoindre une boîte en pleine croissance sur un créneau porteur (tu
# >> as pu noter que Google venait de rentrer dans la danse…)
# >> - Bosser avec des experts Python / Infra / ML qui te feront
# >> progresser à vitesse grand V !
# >> - (pour la data) des « data mentoring » mensuels à Etienne De
# >> Rocquigny, ancien directeur du centre de recherche de Centrale Paris
# >> - Pouvoir choisir entre un MAC et un PC (VM Linux)
# >> - Des Paylead Bars tous les mois
# >> - Du café et des snacks à disposition
# >> - Profiter de notre politique « remote friendly »
# >> - Des tickets restos via la carte Lunchr
# >> - Etc.
# >>
# >>
# >>
# >> Je joins à cet email notre promesse d’embauche.
# >>
# >> J’inclus également Charles notre CEO dans cet email, je te propose qu’il
# >> te partage dans un meeting à venir sa vision du marché, de Paylead, de
# >> l’équipe data et son énergie !
# >>
# >>
# >>
# >> Je reste évidemment dispo pour toute question
# >>
# >>
# >>
# >> A bientôt !
# >>
# >>
# >>
# >> alexis
# >>
# >>
# >>
# >> NB : pour conclure une petite énigme qu’on m’a posée cette semaine.
# >> Combien de personnes faut-il dans une salle pour que la probabilité que 2
# >> d’entre elles ait le même anniversaire soit supérieure à 50% ?
# >>
# >>
# >>
# >>
# >>
# >
# >
# > --
# > --
# >
# > *Charles de Gastines*
# > CEO - Co-founder
# > + 33 (0) 6 80 16 27 82
# > Twitter
# > <
# > | LinkedIn
# > <
# >
# > [image: PayLead - Knowledge to inspire the right purchase]
# > < marketing budget into purchasing power*
# > 69 rue d'hauteville 75010 Paris
# >
# >
#  Bonsoir Charles,
# Merci. Je serais également ravi que tu puisses me parler de votre vision et stratégie.Est-tu disponible la semaine prochaine ?
# Bien à toi,
# Turc Etienne
# Le ven. 15 nov. 2019 à 19:11, Charles de Gastines <charles.degastines@paylead.fr> a écrit :
# > Bonsoir Etienne,
# Je te confirme que nous serions en effet ravi de t'avoir à nos côtés dans notre aventures.Si cela t'intéresse je serais ravi de te parler de notre vision et de notre stratégie sur ce passionnant marché en ébullition !
# À ta disposition,
# Bon WE++
#
# Charles
#
#
# Le ven. 15 nov. 2019 à 12:28, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Hello Etienne,
#
#
#
# Comme discuté au téléphone, nous serions très heureux de te compter parmi nous à partir d’avril.
#
# Ton profil mi data / mi tech serait hyper complémentaire avec le reste de l’équipe et ce stage, s’il est réussi, pourrait naturellement déboucher sur une embauche.
#
#
#
# Rejoindre Paylead aujourd’hui c’est :
#
#  * Rejoindre une boîte en pleine croissance sur un créneau porteur (tu as pu noter que Google venait de rentrer dans la danse…)
#  * Bosser avec des experts Python / Infra / ML qui te feront progresser à vitesse grand V !
#  * (pour la data) des « data mentoring » mensuels à Etienne De Rocquigny, ancien directeur du centre de recherche de Centrale Paris
#  * Pouvoir choisir entre un MAC et un PC (VM Linux)
#  * Des Paylead Bars tous les mois
#  * Du café et des snacks à disposition
#  * Profiter de notre politique « remote friendly »
#  * Des tickets restos via la carte Lunchr
#  * Etc.
#
#
#
# Je joins à cet email notre promesse d’embauche.
#
# J’inclus également Charles notre CEO dans cet email, je te propose qu’il te partage dans un meeting à venir sa vision du marché, de Paylead, de l’équipe data et son énergie !
#
#
#
# Je reste évidemment dispo pour toute question
#
#
#
# A bientôt !
#
#
#
# alexis
#
#
#
# NB : pour conclure une petite énigme qu’on m’a posée cette semaine. Combien de personnes faut-il dans une salle pour que la probabilité que 2 d’entre elles ait le même anniversaire soit supérieure à 50% ?
#
#
#
#
#
#
#
#
# --
# --
#
# Charles de Gastines
# CEO - Co-founder
# + 33 (0) 6 80 16 27 82
# Twitter|LinkedIn
#
# Turning marketing budget into purchasing power
# 69 rue d'hauteville 75010 Paris
#
#
#
#
#
#   Bonjour,
#
# Très bien, c'est noté.
#
# À demain,
#
# Cordialement
#
# Le mer. 13 nov. 2019 à 15:23, Jean-Philippe SERAFIN <
# jean-philippe.serafin@paylead.fr> a écrit :
#
# > Bonjour,
# >
# > dispo aussi.
# >
# > A demain,
# >
# > Le mer. 13 nov. 2019 à 13:07, Loic ROWE <loic.rowe@paylead.fr> a écrit :
# >
# >> Hello Etienne,
# >>
# >> Je serais dispo Jeudi 14 a 18h.
# >> Je vais t'envoyer une invitation ça sera via une visioconférence par
# >> contre.
# >>
# >> Cordialement,
# >>
# >> Le ven. 8 nov. 2019 à 11:51, Alexis Deudon <alexis.deudon@paylead.fr> a
# >> écrit :
# >>
# >>> Parfait !
# >>>
# >>>
# >>>
# >>> *De : *etienne Turc <etienne.turc@gmail.com>
# >>> *Date : *vendredi 8 novembre 2019 à 11:33
# >>> *À : *Alexis Deudon <alexis.deudon@paylead.fr>
# >>> *Cc : *Loic ROWE <loic.rowe@paylead.fr>, Jean-Philippe SERAFIN <
# >>> jean-philippe.serafin@paylead.fr>, Mathilde Gallois <
# >>> mathilde.gallois@paylead.fr>, Antoine Grelety <
# >>> antoine.grelety@paylead.fr>
# >>> *Objet : *Re: Stage Data Engineer chez Paylead
# >>>
# >>>
# >>>
# >>> Salut Alexis,
# >>>
# >>>
# >>>
# >>> Merci pour ton retour.
# >>>
# >>>
# >>>
# >>> L'offre de stage correspond à mes attentes.
# >>>
# >>>
# >>>
# >>> Je prends contact avec Jean-Philippe et Loïc afin de fixer un
# >>> rendez-vous.
# >>>
# >>>
# >>>
# >>> Bien à toi,
# >>>
# >>>
# >>>
# >>> Etienne
# >>>
# >>>
# >>>
# >>> Le mer. 6 nov. 2019 à 15:19, Alexis Deudon <alexis.deudon@paylead.fr> a
# >>> écrit :
# >>>
# >>> Hello Etienne
# >>>
# >>>
# >>>
# >>> Merci encore pour ton temps hier.
# >>>
# >>> Le feedback de l’équipe est très positif et nous sommes vraiment motivés
# >>> pour poursuivre le process avec toi
# >>>
# >>>
# >>>
# >>> Comme promis tu trouveras ci-dessous le contenu du stage formalisé. Je
# >>> peux t’assurer qu’il est pleinement en lien avec nos problématiques
# >>> actuelles 😊 . Bon évidemment il y en a sûrement pour plus de 6 mois,
# >>> nous prioriserons en temps voulu
# >>>
# >>>
# >>>
# >>> Je mets également en cc JP (dev senior backend et bien plus !) et Loïc
# >>> (CTO) pour que vous conveniez d’un rdv (potentiellement à distance) dans
# >>> les prochains jours
# >>>
# >>>
# >>>
# >>> En cas de question je reste évidemment à ta disposition.
# >>>
# >>>
# >>>
# >>> A bientôt !
# >>>
# >>>
# >>>
# >>> Alexis
# >>>
# >>>
# >>>
# >>> *Industrialisation du déploiement des modèles de Machine Learning*
# >>>
# >>>
# >>>
# >>> La fintech Paylead est leader dans l’analyse de la donnée de transaction
# >>> bancaire. En particulier la startup développe des moteurs de machine
# >>> learning avec 2 objectifs principaux:
# >>>
# >>> - contextualiser une transaction bancaire (enseigne, ville, magasin,
# >>> univers, type…)
# >>> - Découvrir à partir de ces transactions enrichies des patterns de
# >>> consommation
# >>>
# >>>
# >>>
# >>> Le nombre de modèles en production et en développement chez Paylead
# >>> s’accroit à mesure que la start up grandit et il est aujourd’hui nécessaire
# >>> de systématiser et unifier la manière dont ces modèles sont construits /
# >>> testés et déployés.
# >>>
# >>>
# >>>
# >>> Dans ce cadre le stagiaire « data engineer » aura pour mission de
# >>> construire des briques en vue d’automatiser :
# >>>
# >>> - l’analyse du temps de processing des algorithmes, en particulier
# >>> on s’attachera à exhiber les parties du code les plus longues à processer
# >>> - Le testing fonctionnel des modèles en créant pour chaque modèle un
# >>> univers de test pertinent (à la fois exhaustif et concis)
# >>> - L’analyse des différentes features d’un modèle (corrélation avec
# >>> la variable cible, distribution, etc.)
# >>> - L’explicabilité des prédictions (application de la littérature
# >>> foisonnante sur le sujet)
# >>> - La validation des améliorations apportées aux différents modèles :
# >>> « Peut on vraiment dire que telle ou telle mise à jour améliore
# >>> significativement (au sens statistique) le modèle »
# >>>
# >>>
# >>>
# >>> Compétences recherchées :
# >>>
# >>> - Bonne connaissance des modèles de machine learning
# >>> - Bon niveau en Python et en SQL
# >>> - Autonomie, Curiosité
# >>>
# >>>
# >>>
# >>>
# >>>
# >>>
# >>
# >> --
# >> *Rowe Loïc*
# >> Chief Technical Officer
# >> +33(0)687138943
# >>
# >> [image: PayLead - Knowledge to inspire the right purchase]
# >> < marketing budget into purchasing power*
# >> 69 rue d'hauteville 75010 Paris
# >>
# >
# >
# > --
# > Jean-Philippe Serafin
# >
# >
# >
#  Bonjour,
# Très bien, c'est noté.
# À demain,
# Cordialement
# Le mer. 13 nov. 2019 à 15:23, Jean-Philippe SERAFIN <jean-philippe.serafin@paylead.fr> a écrit :
# > Bonjour,
#
# dispo aussi.
#
# A demain,
# Le mer. 13 nov. 2019 à 13:07, Loic ROWE <loic.rowe@paylead.fr> a écrit :
# > Hello Etienne,
#
# Je serais dispo Jeudi 14 a 18h.
# Je vais t'envoyer une invitation ça sera via une visioconférence par contre.
#
# Cordialement,
# Le ven. 8 nov. 2019 à 11:51, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Parfait !
#
#
#
# De : etienne Turc <etienne.turc@gmail.com>
# Date : vendredi 8 novembre 2019 à 11:33
# À : Alexis Deudon <alexis.deudon@paylead.fr>
# Cc : Loic ROWE <loic.rowe@paylead.fr>, Jean-Philippe SERAFIN <jean-philippe.serafin@paylead.fr>, Mathilde Gallois <mathilde.gallois@paylead.fr>, Antoine Grelety <antoine.grelety@paylead.fr>
# Objet : Re: Stage Data Engineer chez Paylead
#
#
#
# Salut Alexis,
#
#
#
# Merci pour ton retour.
#
#
#
# L'offre de stage correspond à mes attentes.
#
#
#
# Je prends contact avec Jean-Philippe et Loïc afin de fixer un rendez-vous.
#
#
#
# Bien à toi,
#
#
#
# Etienne
#
#
#
# Le mer. 6 nov. 2019 à 15:19, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
#
# > Hello Etienne
#
#
#
# Merci encore pour ton temps hier.
#
# Le feedback de l’équipe est très positif et nous sommes vraiment motivés pour poursuivre le process avec toi
#
#
#
# Comme promis tu trouveras ci-dessous le contenu du stage formalisé. Je peux t’assurer qu’il est pleinement en lien avec nos problématiques actuelles😊. Bon évidemment il y en a sûrement pour plus de 6 mois, nous prioriserons en temps voulu
#
#
#
# Je mets également en cc JP (dev senior backend et bien plus !) et Loïc (CTO) pour que vous conveniez d’un rdv (potentiellement à distance) dans les prochains jours
#
#
#
# En cas de question je reste évidemment à ta disposition.
#
#
#
# A bientôt !
#
#
#
# Alexis
#
#
#
# Industrialisation du déploiement des modèles de Machine Learning
#
#
#
# La fintech Paylead est leader dans l’analyse de la donnée de transaction bancaire. En particulier la startup développe des moteurs de machine learning avec 2 objectifs principaux:
#
#  * contextualiser une transaction bancaire (enseigne, ville, magasin, univers, type…)
#  * Découvrir à partir de ces transactions enrichies des patterns de consommation
#
#
#
# Le nombre de modèles en production et en développement chez Paylead s’accroit à mesure que la start up grandit et il est aujourd’hui nécessaire de systématiser et unifier la manière dont ces modèles sont construits / testés et déployés.
#
#
#
# Dans ce cadre le stagiaire « data engineer » aura pour mission de construire des briques en vue d’automatiser :
#
#  * l’analyse du temps de processing des algorithmes, en particulier on s’attachera à exhiber les parties du code les plus longues à processer
#  * Le testing fonctionnel des modèles en créant pour chaque modèle un univers de test pertinent (à la fois exhaustif et concis)
#  * L’analyse des différentes features d’un modèle (corrélation avec la variable cible, distribution, etc.)
#  * L’explicabilité des prédictions (application de la littérature foisonnante sur le sujet)
#  * La validation des améliorations apportées aux différents modèles : « Peut on vraiment dire que telle ou telle mise à jour améliore significativement (au sens statistique) le modèle »
#
#
#
# Compétences recherchées :
#
#  * Bonne connaissance des modèles de machine learning
#  * Bon niveau en Python et en SQL
#  * Autonomie, Curiosité
#
#
#
#
#
#
#
#
#
# --
# Rowe Loïc
# Chief Technical Officer
# +33(0)687138943
#
# Turning marketing budget into purchasing power
# 69 rue d'hauteville 75010 Paris
#
#
#
# --
# Jean-Philippe Serafin
#
#
#
#
#
#
#
#   Bonjour,
#
# Je vous contacte suite à la réponse d'Alexis. Voici mes disponibilités:
# - Mardi 12 Novembre: 14h00-16h00 / après 18h00.
# - Mercredi 13: après 18h00.
# - Jeudi 14: après 18h00.
# - Vendredi 15: après 17h30.
#
# Bien cordialement,
#
# Etienne
#
# Le mer. 6 nov. 2019 à 15:19, Alexis Deudon <alexis.deudon@paylead.fr> a
# écrit :
#
# > Hello Etienne
# >
# >
# >
# > Merci encore pour ton temps hier.
# >
# > Le feedback de l’équipe est très positif et nous sommes vraiment motivés
# > pour poursuivre le process avec toi
# >
# >
# >
# > Comme promis tu trouveras ci-dessous le contenu du stage formalisé. Je
# > peux t’assurer qu’il est pleinement en lien avec nos problématiques
# > actuelles 😊 . Bon évidemment il y en a sûrement pour plus de 6 mois,
# > nous prioriserons en temps voulu
# >
# >
# >
# > Je mets également en cc JP (dev senior backend et bien plus !) et Loïc
# > (CTO) pour que vous conveniez d’un rdv (potentiellement à distance) dans
# > les prochains jours
# >
# >
# >
# > En cas de question je reste évidemment à ta disposition.
# >
# >
# >
# > A bientôt !
# >
# >
# >
# > Alexis
# >
# >
# >
# > *Industrialisation du déploiement des modèles de Machine Learning*
# >
# >
# >
# > La fintech Paylead est leader dans l’analyse de la donnée de transaction
# > bancaire. En particulier la startup développe des moteurs de machine
# > learning avec 2 objectifs principaux:
# >
# > - contextualiser une transaction bancaire (enseigne, ville, magasin,
# > univers, type…)
# > - Découvrir à partir de ces transactions enrichies des patterns de
# > consommation
# >
# >
# >
# > Le nombre de modèles en production et en développement chez Paylead
# > s’accroit à mesure que la start up grandit et il est aujourd’hui nécessaire
# > de systématiser et unifier la manière dont ces modèles sont construits /
# > testés et déployés.
# >
# >
# >
# > Dans ce cadre le stagiaire « data engineer » aura pour mission de
# > construire des briques en vue d’automatiser :
# >
# > - l’analyse du temps de processing des algorithmes, en particulier on
# > s’attachera à exhiber les parties du code les plus longues à processer
# > - Le testing fonctionnel des modèles en créant pour chaque modèle un
# > univers de test pertinent (à la fois exhaustif et concis)
# > - L’analyse des différentes features d’un modèle (corrélation avec la
# > variable cible, distribution, etc.)
# > - L’explicabilité des prédictions (application de la littérature
# > foisonnante sur le sujet)
# > - La validation des améliorations apportées aux différents modèles :
# > « Peut on vraiment dire que telle ou telle mise à jour améliore
# > significativement (au sens statistique) le modèle »
# >
# >
# >
# > Compétences recherchées :
# >
# > - Bonne connaissance des modèles de machine learning
# > - Bon niveau en Python et en SQL
# > - Autonomie, Curiosité
# >
# >
# >
# >
# >
#  Bonjour,
# Je vous contacte suite à la réponse d'Alexis. Voici mes disponibilités:- Mardi 12 Novembre: 14h00-16h00 / après 18h00.- Mercredi 13: après 18h00.- Jeudi 14: après 18h00.- Vendredi 15: après 17h30.
# Bien cordialement,
# Etienne
# Le mer. 6 nov. 2019 à 15:19, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Hello Etienne
#
#
#
# Merci encore pour ton temps hier.
#
# Le feedback de l’équipe est très positif et nous sommes vraiment motivés pour poursuivre le process avec toi
#
#
#
# Comme promis tu trouveras ci-dessous le contenu du stage formalisé. Je peux t’assurer qu’il est pleinement en lien avec nos problématiques actuelles😊. Bon évidemment il y en a sûrement pour plus de 6 mois, nous prioriserons en temps voulu
#
#
#
# Je mets également en cc JP (dev senior backend et bien plus !) et Loïc (CTO) pour que vous conveniez d’un rdv (potentiellement à distance) dans les prochains jours
#
#
#
# En cas de question je reste évidemment à ta disposition.
#
#
#
# A bientôt !
#
#
#
# Alexis
#
#
#
# Industrialisation du déploiement des modèles de Machine Learning
#
#
#
# La fintech Paylead est leader dans l’analyse de la donnée de transaction bancaire. En particulier la startup développe des moteurs de machine learning avec 2 objectifs principaux:
#
#  * contextualiser une transaction bancaire (enseigne, ville, magasin, univers, type…)
#  * Découvrir à partir de ces transactions enrichies des patterns de consommation
#
#
#
# Le nombre de modèles en production et en développement chez Paylead s’accroit à mesure que la start up grandit et il est aujourd’hui nécessaire de systématiser et unifier la manière dont ces modèles sont construits / testés et déployés.
#
#
#
# Dans ce cadre le stagiaire « data engineer » aura pour mission de construire des briques en vue d’automatiser :
#
#  * l’analyse du temps de processing des algorithmes, en particulier on s’attachera à exhiber les parties du code les plus longues à processer
#  * Le testing fonctionnel des modèles en créant pour chaque modèle un univers de test pertinent (à la fois exhaustif et concis)
#  * L’analyse des différentes features d’un modèle (corrélation avec la variable cible, distribution, etc.)
#  * L’explicabilité des prédictions (application de la littérature foisonnante sur le sujet)
#  * La validation des améliorations apportées aux différents modèles : « Peut on vraiment dire que telle ou telle mise à jour améliore significativement (au sens statistique) le modèle »
#
#
#
# Compétences recherchées :
#
#  * Bonne connaissance des modèles de machine learning
#  * Bon niveau en Python et en SQL
#  * Autonomie, Curiosité
#
#
#
#
#
#   Salut Alexis,
#
# Merci pour ton retour.
#
# L'offre de stage correspond à mes attentes.
#
# Je prends contact avec Jean-Philippe et Loïc afin de fixer un rendez-vous.
#
# Bien à toi,
#
# Etienne
#
# Le mer. 6 nov. 2019 à 15:19, Alexis Deudon <alexis.deudon@paylead.fr> a
# écrit :
#
# > Hello Etienne
# >
# >
# >
# > Merci encore pour ton temps hier.
# >
# > Le feedback de l’équipe est très positif et nous sommes vraiment motivés
# > pour poursuivre le process avec toi
# >
# >
# >
# > Comme promis tu trouveras ci-dessous le contenu du stage formalisé. Je
# > peux t’assurer qu’il est pleinement en lien avec nos problématiques
# > actuelles 😊 . Bon évidemment il y en a sûrement pour plus de 6 mois,
# > nous prioriserons en temps voulu
# >
# >
# >
# > Je mets également en cc JP (dev senior backend et bien plus !) et Loïc
# > (CTO) pour que vous conveniez d’un rdv (potentiellement à distance) dans
# > les prochains jours
# >
# >
# >
# > En cas de question je reste évidemment à ta disposition.
# >
# >
# >
# > A bientôt !
# >
# >
# >
# > Alexis
# >
# >
# >
# > *Industrialisation du déploiement des modèles de Machine Learning*
# >
# >
# >
# > La fintech Paylead est leader dans l’analyse de la donnée de transaction
# > bancaire. En particulier la startup développe des moteurs de machine
# > learning avec 2 objectifs principaux:
# >
# > - contextualiser une transaction bancaire (enseigne, ville, magasin,
# > univers, type…)
# > - Découvrir à partir de ces transactions enrichies des patterns de
# > consommation
# >
# >
# >
# > Le nombre de modèles en production et en développement chez Paylead
# > s’accroit à mesure que la start up grandit et il est aujourd’hui nécessaire
# > de systématiser et unifier la manière dont ces modèles sont construits /
# > testés et déployés.
# >
# >
# >
# > Dans ce cadre le stagiaire « data engineer » aura pour mission de
# > construire des briques en vue d’automatiser :
# >
# > - l’analyse du temps de processing des algorithmes, en particulier on
# > s’attachera à exhiber les parties du code les plus longues à processer
# > - Le testing fonctionnel des modèles en créant pour chaque modèle un
# > univers de test pertinent (à la fois exhaustif et concis)
# > - L’analyse des différentes features d’un modèle (corrélation avec la
# > variable cible, distribution, etc.)
# > - L’explicabilité des prédictions (application de la littérature
# > foisonnante sur le sujet)
# > - La validation des améliorations apportées aux différents modèles :
# > « Peut on vraiment dire que telle ou telle mise à jour améliore
# > significativement (au sens statistique) le modèle »
# >
# >
# >
# > Compétences recherchées :
# >
# > - Bonne connaissance des modèles de machine learning
# > - Bon niveau en Python et en SQL
# > - Autonomie, Curiosité
# >
# >
# >
# >
# >
#  Salut Alexis,
# Merci pour ton retour.
# L'offre de stage correspond à mes attentes.
# Je prends contact avec Jean-Philippe et Loïc afin de fixer un rendez-vous.
# Bien à toi,
# Etienne
# Le mer. 6 nov. 2019 à 15:19, Alexis Deudon <alexis.deudon@paylead.fr> a écrit :
# > Hello Etienne
#
#
#
# Merci encore pour ton temps hier.
#
# Le feedback de l’équipe est très positif et nous sommes vraiment motivés pour poursuivre le process avec toi
#
#
#
# Comme promis tu trouveras ci-dessous le contenu du stage formalisé. Je peux t’assurer qu’il est pleinement en lien avec nos problématiques actuelles😊. Bon évidemment il y en a sûrement pour plus de 6 mois, nous prioriserons en temps voulu
#
#
#
# Je mets également en cc JP (dev senior backend et bien plus !) et Loïc (CTO) pour que vous conveniez d’un rdv (potentiellement à distance) dans les prochains jours
#
#
#
# En cas de question je reste évidemment à ta disposition.
#
#
#
# A bientôt !
#
#
#
# Alexis
#
#
#
# Industrialisation du déploiement des modèles de Machine Learning
#
#
#
# La fintech Paylead est leader dans l’analyse de la donnée de transaction bancaire. En particulier la startup développe des moteurs de machine learning avec 2 objectifs principaux:
#
#  * contextualiser une transaction bancaire (enseigne, ville, magasin, univers, type…)
#  * Découvrir à partir de ces transactions enrichies des patterns de consommation
#
#
#
# Le nombre de modèles en production et en développement chez Paylead s’accroit à mesure que la start up grandit et il est aujourd’hui nécessaire de systématiser et unifier la manière dont ces modèles sont construits / testés et déployés.
#
#
#
# Dans ce cadre le stagiaire « data engineer » aura pour mission de construire des briques en vue d’automatiser :
#
#  * l’analyse du temps de processing des algorithmes, en particulier on s’attachera à exhiber les parties du code les plus longues à processer
#  * Le testing fonctionnel des modèles en créant pour chaque modèle un univers de test pertinent (à la fois exhaustif et concis)
#  * L’analyse des différentes features d’un modèle (corrélation avec la variable cible, distribution, etc.)
#  * L’explicabilité des prédictions (application de la littérature foisonnante sur le sujet)
#  * La validation des améliorations apportées aux différents modèles : « Peut on vraiment dire que telle ou telle mise à jour améliore significativement (au sens statistique) le modèle »
#
#
#
# Compétences recherchées :
#
#  * Bonne connaissance des modèles de machine learning
#  * Bon niveau en Python et en SQL
#  * Autonomie, Curiosité
#
#
#
#
#
#   Voila les informations pour vol retour.
#
# ---------- Forwarded message ---------
# De : confirmation@easyJet.com <donotreply@easyjet.com>
# Date: sam. 6 avr. 2019 à 14:21
# Subject: easyJet référence de réservation: EWXGJ4S
# To: <etienne.turc@gmail.com>
#
#
# ETIENNE, voici les détails de votre réservation EWXGJ4S
# *Étapes suivantes*
# • S’enregistrer en ligne
# (L'enregistrement est disponible 30 jours avant la date de votre vol.)
# • Obtenir vos cartes d’embarquement
# Gérer vos réservations >
# <
# *Détails du paiement*
# Paiement de 88,95 € avant Carte Bleue sur 06/04/2019
# Envoyez-moi par e-mail la confirmation de mon paiement intégral >
# <
# Envoyez-moi par e-mail la facture avec TVA >
# <
# *Informations détaillées sur les passagers et les vols 1 de 1*
# Berlin Tegel (Terminal C) à Bâle(Basel)-Mulhouse-Fribourg
# EZS4637 [image: flight]
# ------------------------------
# Départ : sam. 27 juil. 13:50
# Arrivée : sam. 27 juil. 15:25
# Le comptoir dépose bagages ouvre : sam. 27 juil. 11:50
# Le comptoir dépose-bagages ferme : sam. 27 juil. 13:10
# L’enregistrement ferme 40 minutes avant l’heure de départ prévue
# M ETIENNE TURC Siège voiture attribuée
#
# Ajouter des sièges
# <
# Ajouter des articles
# <
# Changer de vol
# <
# *Bagage en soute*
# Bagage à main Taille maximale 56 x 45 x 25 cm
#
# Les compartiments au-dessus de vos têtes ne disposent que de 70 places pour
# les bagages à main, ils se rempliront donc rapidement. Tous les autres
# bagages à main seront placés en soute.
# Bagages en soute 1 x 23kg du bagage en soute
# *Avertissement assistance spéciale et allergie aux noix*
# Veuillez nous indiquer, au plus tard 48 heures avant le départ de votre
# vol, si vous avez besoin d’assistance à l’aéroport et dans l’avion ou si
# vous souffrez d’une allergie aux noix afin que nous puissions en informer
# notre équipage avant votre arrivée à l’aéroport.
# Les passagers ayant besoin d’une assistance à l’aéroport doivent arriver au
# moins 90 minutes avant le départ du vol.
#
# Ajouter une demande de services spéciaux
# <
# Ajouter un avertissement allergie aux noix
# <
# *Gérer vos réservations...
# <
# Rendez-vous sur Vos réservations pour toutes vos actions : ajout ou
# modification de sièges ou de bagages en soute, modification des
# informations passagers, changement de vols...
# <
# <
# *easyJet App <
# Téléchargez notre application pour iPhone et téléphones Android. Réservez
# et gérez vos vols où que vous soyez avec easyJet mobile.
# < <
# *Flight Tracker <
# Pour connaître les informations les plus récentes en lien avec votre vol,
# rendez-vous sur le Flight Tracker d’easyJet.
# <
# <
# *Contactez-nous !*
# < <
# <
# *Annulations et remboursements*
# Les taxes gouvernementales (si il y en a) sont remboursables pour cette
# reservation si vous décidez de ne pas voyager. En savior plus.
# <
# *Politique d’annulation dans les 24 heures*
# Vous pouvez annuler l’intégralité de votre réservation moins de 24 heures
# après l’avoir effectuée. Nous vous rembourserons l’intégralité du montant
# après déduction des frais d’annulation. Consultez notre page Aide pour
# obtenir plus d’informations.
# <
# * Aide et assistance *
# *S’enregistrer en ligne*
# <
# <
# *Assistance spéciale*
# <
# <
# *Franchise de bagage*
# <
# <
# *Siège*
# <
# <
# *Gérer des vols*
# <
# <
# *Flight Tracker* <
# <
# *Vous voyagez avec des enfants ?*
# <
# <
# *Données relatives aux passagers*
# <
# <
# *Vous avez une autre question ? * [image: arrow]
# <
# *Informations utiles*
# *À l’enregistrement*
# La compagnie aérienne easyJet ne délivre pas de billets. Votre passeport en
# cours de validité suffit pour vous enregistrer. Vous n’avez pas besoin de
# nous contacter pour reconfirmer.
# *L’enregistrement en ligne* est disponible 30 jours avant le départ prévu
# du vol et ferme 2 heures avant.
# Une pièce d’identité valide avec photo
# < est exigée pour
# tous les vols, y compris pour les services intérieurs.
# *Bagages*
# Faites attention lorsque vous préparez vos bagages. Aucun objet dangereux
# ne doit être mis dans les bagages et certains articles peuvent uniquement
# être transportés dans certaines parties de l’avion. Veillez à être en règle
# avec nos règlements relatifs aux bagages de soute et à main
# < à tout moment.
# *Termes du contrat*
# Le transport est soumis aux tarifs applicables, aux conditions générales
# < et aux règlements afférents
# < qui sont présentés sur ce
# site ou peuvent être obtenus gratuitement sur demande auprès du bureau du
# transporteur. Le transporteur ci-après est soumis aux règles et limitations
# concernant la responsabilité établies par la Convention de Montréal.
# *Remarque importante*
# Si le voyage du passager se finit ou fait escale dans une destination autre
# que le pays de départ, la Convention de Montréal est applicable, et la
# Convention régit et dans la plupart des cas, limite la responsabilité des
# transporteurs concernant la mort ou les blessures personnelles, ou encore
# la perte ou l’endommagement des bagages.
# *Europcar conditions-generales
# <
# Pourquoi nous vous contactons ? Vous avez reçu cet e-mail de confirmation
# car vous avez effectué une réservation avec easyJet.
# Cette vente n’est pas couverte par le système ATOL
# <
#
# *INFORMATIONS D’ABONNEMENT*
#
# Pas d’inquiétude, nous savons que vous ne souhaitez pas recevoir d’e-mails
# marketing de notre part.
# Si vous avez contacté notre équipe service clientèle et à défaut de réponse
# satisfaisante dans un délai de soixante (60) jours, vous pouvez contacter
# La Médiation Tourisme et Voyage.
# Les coordonnées et informations relatives à la procédure sont disponibles
# sur son site www.mtv.travel
# *1997-2019 easyJet airline company ltd. Tous droits réservés.*
#  Voila les informations pour vol retour.
#
# ---------- Forwarded message ---------
# De : confirmation@easyJet.com <donotreply@easyjet.com>
# Date: sam. 6 avr. 2019 à 14:21
# Subject: easyJet référence de réservation: EWXGJ4S
# To: <etienne.turc@gmail.com>
#
#
# ETIENNE, voici les détails de votre réservation EWXGJ4S Étapes suivantes • S’enregistrer en ligne
# (L'enregistrement est disponible 30 jours avant la date de votre vol.) • Obtenir vos cartes d’embarquement Gérer vos réservations > Détails du paiement Paiement de 88,95 € avant Carte Bleue sur 06/04/2019 Envoyez-moi par e-mail la confirmation de mon paiement intégral > Envoyez-moi par e-mail la facture avec TVA > Informations détaillées sur les passagers et les vols 1 de 1 Berlin Tegel (Terminal C) à Bâle(Basel)-Mulhouse-Fribourg EZS4637
#
#
# Départ : sam. 27 juil. 13:50 Arrivée : sam. 27 juil. 15:25 Le comptoir dépose bagages ouvre : sam. 27 juil. 11:50 Le comptoir dépose-bagages ferme : sam. 27 juil. 13:10 L’enregistrement ferme 40 minutes avant l’heure de départ prévue M ETIENNE TURC Siège voiture attribuée Ajouter des sièges Ajouter des articles Changer de vol Bagage en soute Bagage à main Taille maximale 56 x 45 x 25 cm Les compartiments au-dessus de vos têtes ne disposent que de 70 places pour les bagages à main, ils se rempliront donc rapidement. Tous les autres bagages à main seront placés en soute.
#
# Bagages en soute 1 x 23kg du bagage en soute
# Avertissement assistance spéciale et allergie aux noix Veuillez nous indiquer, au plus tard 48 heures avant le départ de votre vol, si vous avez besoin d’assistance à l’aéroport et dans l’avion ou si vous souffrez d’une allergie aux noix afin que nous puissions en informer notre équipage avant votre arrivée à l’aéroport. Les passagers ayant besoin d’une assistance à l’aéroport doivent arriver au moins 90 minutes avant le départ du vol. Ajouter une demande de services spéciaux Ajouter un avertissement allergie aux noix Gérer vos réservations... Rendez-vous sur Vos réservations pour toutes vos actions : ajout ou modification de sièges ou de bagages en soute, modification des informations passagers, changement de vols... easyJet App Téléchargez notre application pour iPhone et téléphones Android. Réservez et gérez vos vols où que vous soyez avec easyJet mobile. Flight Tracker Pour connaître les informations les plus récentes en lien avec votre vol, rendez-vous sur le Flight Tracker d’easyJet. Contactez-nous ! Annulations et remboursements Les taxes gouvernementales (si il y en a) sont remboursables pour cette reservation si vous décidez de ne pas voyager. En savior plus. Politique d’annulation dans les 24 heures Vous pouvez annuler l’intégralité de votre réservation moins de 24 heures après l’avoir effectuée. Nous vous rembourserons l’intégralité du montant après déduction des frais d’annulation. Consultez notre page Aide pour obtenir plus d’informations. Aide et assistance S’enregistrer en ligne Assistance spéciale Franchise de bagage Siège Gérer des vols Flight Tracker Vous voyagez avec des enfants ? Données relatives aux passagers Vous avez une autre question ? Informations utiles À l’enregistrement La compagnie aérienne easyJet ne délivre pas de billets. Votre passeport en cours de validité suffit pour vous enregistrer. Vous n’avez pas besoin de nous contacter pour reconfirmer. L’enregistrement en ligne est disponible 30 jours avant le départ prévu du vol et ferme 2 heures avant. Une pièce d’identité valide avec photo est exigée pour tous les vols, y compris pour les services intérieurs. Bagages Faites attention lorsque vous préparez vos bagages. Aucun objet dangereux ne doit être mis dans les bagages et certains articles peuvent uniquement être transportés dans certaines parties de l’avion. Veillez à être en règle avec nos règlements relatifs aux bagages de soute et à main à tout moment. Termes du contrat Le transport est soumis aux tarifs applicables, aux conditions générales et aux règlements afférents qui sont présentés sur ce site ou peuvent être obtenus gratuitement sur demande auprès du bureau du transporteur. Le transporteur ci-après est soumis aux règles et limitations concernant la responsabilité établies par la Convention de Montréal. Remarque importante Si le voyage du passager se finit ou fait escale dans une destination autre que le pays de départ, la Convention de Montréal est applicable, et la Convention régit et dans la plupart des cas, limite la responsabilité des transporteurs concernant la mort ou les blessures personnelles, ou encore la perte ou l’endommagement des bagages. *Europcar conditions-generales Pourquoi nous vous contactons ? Vous avez reçu cet e-mail de confirmation car vous avez effectué une réservation avec easyJet.
# Cette vente n’est pas couverte par le système ATOL
#
# INFORMATIONS D’ABONNEMENT
#
# Pas d’inquiétude, nous savons que vous ne souhaitez pas recevoir d’e-mails marketing de notre part. Si vous avez contacté notre équipe service clientèle et à défaut de réponse satisfaisante dans un délai de soixante (60) jours, vous pouvez contacter La Médiation Tourisme et Voyage.
# Les coordonnées et informations relatives à la procédure sont disponibles sur son site www.mtv.travel 1997-2019 easyJet airline company ltd. Tous droits réservés.
#
#
#
#
#
#   Hello Mrs. Hoffman,
#
# I am responding to your post on wg-gesucht.com (
#
# I am interested in the appartement.
#
# I am a French engineer student looking for housing starting 01.06.2019
# until 27.07.2019. I am doing a research internship in Berlin in computer
# science at FU. So you won't be surprise if I tell you that I like to
# program (at work and during my free time). I also like to play basket and
# to do some magic tricks. I am more of a quiet person but I like to hang out
# times to times. I am also pretty curious. And I don't smoke.
#
# Is it possible to have some picture of the apartment? And to visit it ?
#
# I also would like to know what is included in the rent?
#
# Best regards,
#  Hello Mrs. Hoffman,
# I am responding to your post on wg-gesucht.com ( I am interested in the appartement.
# ...
# > voila les photos, j'ai marqué a quoi ça correspondait en dessous
#
#
#
#
#
#   bon ben imprime en noir et blanc
#
# Le 1 octobre 2012 19:23, Valentin THIERRY <valenthierry@free.fr> a écrit :
#
# > **
# > moi non plus, j'ai jamaios d'encre de couleur
# >
# >
# > ----- Original Message -----
# > *From:* etienne Turc <etienne.turc@gmail.com>
# > *To:* Valentin THIERRY <valenthierry@free.fr>
# > *Sent:* Monday, October 01, 2012 7:20 PM
# > *Subject:* Re: images
# >
# > demande a dino et moi j'ai plus de crédit
# > et essaye quand même stp car moi c pas de la merde ce que je te dit
# >
# > Le 1 octobre 2012 19:10, Valentin THIERRY <valenthierry@free.fr> a écrit :
# >
# >> **
# >> j'ai pas d'encre non plus
# >>
# >> ----- Original Message -----
# >> *From:* etienne Turc <etienne.turc@gmail.com>
# >> *To:* Valentin THIERRY <valenthierry@free.fr>
# >> *Sent:* Monday, October 01, 2012 6:51 PM
# >> *Subject:* Re: images
# >>
# >> pages Les 2 premières pages stp
# >>
# >>
# >> Le 1 octobre 2012 18:51, etienne Turc <etienne.turc@gmail.com> a écrit :
# >>
# >>> imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
# >>>
# >>> Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a
# >>> écrit :
# >>>
# >>> **
# >>>> ok ça marche
# >>>>
# >>>> ----- Original Message -----
# >>>> *From:* etienne Turc <etienne.turc@gmail.com>
# >>>> *To:* Valentin THIERRY <valenthierry@free.fr>
# >>>> *Sent:* Monday, October 01, 2012 6:33 PM
# >>>> *Subject:* Re: images
# >>>>
# >>>> eh je colle pas les images on voit sa demain pendant le temps de midi
# >>>> juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
# >>>>
# >>>> Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a
# >>>> écrit :
# >>>>
# >>>>> **
# >>>>> ouai parffait
# >>>>>
# >>>>> ----- Original Message -----
# >>>>> *From:* etienne Turc <etienne.turc@gmail.com>
# >>>>> *To:* Valentin THIERRY <valenthierry@free.fr>
# >>>>> *Sent:* Monday, October 01, 2012 6:29 PM
# >>>>> *Subject:* Re: images
# >>>>>
# >>>>> =ce serait bien de mettre ces photos la aussi
# >>>>>
# >>>>> Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a
# >>>>> écrit :
# >>>>>
# >>>>>> **
# >>>>>> voila les photos, j'ai marqué a quoi ça correspondait en dessous
# >>>>>>
# >>>>>
# >>>>>
# >>>>
# >>>
# >>
# >
#  bon ben imprime en noir et blanc
#
# Le 1 octobre 2012 19:23, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > moi non plus, j'ai jamaios d'encre de couleur> ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 7:20 PM Subject: Re: images
# demande a dino et moi j'ai plus de crédit et essaye quand même stp car moi c pas de la merde ce que je te dit
#
# Le 1 octobre 2012 19:10, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > j'ai pas d'encre non plus > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:51 PM Subject: Re: images
# pages Les 2 premières pages stp
#
# Le 1 octobre 2012 18:51, etienne Turc <etienne.turc@gmail.com> a écrit :
# > imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
#
# Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ok ça marche > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:33 PM Subject: Re: images
# eh je colle pas les images on voit sa demain pendant le temps de midi juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
#
# Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ouai parffait > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:29 PM Subject: Re: images
# =ce serait bien de mettre ces photos la aussi
# Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila les photos, j'ai marqué a quoi ça correspondait en dessous
#
#
#
#
#
#   demande a dino et moi j'ai plus de crédit
# et essaye quand même stp car moi c pas de la merde ce que je te dit
#
# Le 1 octobre 2012 19:10, Valentin THIERRY <valenthierry@free.fr> a écrit :
#
# > **
# > j'ai pas d'encre non plus
# >
# > ----- Original Message -----
# > *From:* etienne Turc <etienne.turc@gmail.com>
# > *To:* Valentin THIERRY <valenthierry@free.fr>
# > *Sent:* Monday, October 01, 2012 6:51 PM
# > *Subject:* Re: images
# >
# > pages Les 2 premières pages stp
# >
# >
# > Le 1 octobre 2012 18:51, etienne Turc <etienne.turc@gmail.com> a écrit :
# >
# >> imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
# >>
# >> Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit
# >> :
# >>
# >> **
# >>> ok ça marche
# >>>
# >>> ----- Original Message -----
# >>> *From:* etienne Turc <etienne.turc@gmail.com>
# >>> *To:* Valentin THIERRY <valenthierry@free.fr>
# >>> *Sent:* Monday, October 01, 2012 6:33 PM
# >>> *Subject:* Re: images
# >>>
# >>> eh je colle pas les images on voit sa demain pendant le temps de midi
# >>> juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
# >>>
# >>> Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a
# >>> écrit :
# >>>
# >>>> **
# >>>> ouai parffait
# >>>>
# >>>> ----- Original Message -----
# >>>> *From:* etienne Turc <etienne.turc@gmail.com>
# >>>> *To:* Valentin THIERRY <valenthierry@free.fr>
# >>>> *Sent:* Monday, October 01, 2012 6:29 PM
# >>>> *Subject:* Re: images
# >>>>
# >>>> =ce serait bien de mettre ces photos la aussi
# >>>>
# >>>> Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a
# >>>> écrit :
# >>>>
# >>>>> **
# >>>>> voila les photos, j'ai marqué a quoi ça correspondait en dessous
# >>>>>
# >>>>
# >>>>
# >>>
# >>
# >
#  demande a dino et moi j'ai plus de créditet essaye quand même stp car moi c pas de la merde ce que je te dit
#
# Le 1 octobre 2012 19:10, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > j'ai pas d'encre non plus> ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:51 PM Subject: Re: images
# pages Les 2 premières pages stp
#
# Le 1 octobre 2012 18:51, etienne Turc <etienne.turc@gmail.com> a écrit :
# > imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
#
# Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ok ça marche > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:33 PM Subject: Re: images
# eh je colle pas les images on voit sa demain pendant le temps de midi juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
#
# Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ouai parffait > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:29 PM Subject: Re: images
# =ce serait bien de mettre ces photos la aussi
# Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila les photos, j'ai marqué a quoi ça correspondait en dessous
#
#
#
#
#
#   pages Les 2 premières pages stp
#
#
# Le 1 octobre 2012 18:51, etienne Turc <etienne.turc@gmail.com> a écrit :
#
# > imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
# >
# > Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit :
# >
# > **
# >> ok ça marche
# >>
# >> ----- Original Message -----
# >> *From:* etienne Turc <etienne.turc@gmail.com>
# >> *To:* Valentin THIERRY <valenthierry@free.fr>
# >> *Sent:* Monday, October 01, 2012 6:33 PM
# >> *Subject:* Re: images
# >>
# >> eh je colle pas les images on voit sa demain pendant le temps de midi
# >> juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
# >>
# >> Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit
# >> :
# >>
# >>> **
# >>> ouai parffait
# >>>
# >>> ----- Original Message -----
# >>> *From:* etienne Turc <etienne.turc@gmail.com>
# >>> *To:* Valentin THIERRY <valenthierry@free.fr>
# >>> *Sent:* Monday, October 01, 2012 6:29 PM
# >>> *Subject:* Re: images
# >>>
# >>> =ce serait bien de mettre ces photos la aussi
# >>>
# >>> Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a
# >>> écrit :
# >>>
# >>>> **
# >>>> voila les photos, j'ai marqué a quoi ça correspondait en dessous
# >>>>
# >>>
# >>>
# >>
# >
#  pages Les 2 premières pages stp
#
# Le 1 octobre 2012 18:51, etienne Turc <etienne.turc@gmail.com> a écrit :
# > imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
#
# Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ok ça marche > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:33 PM Subject: Re: images
# eh je colle pas les images on voit sa demain pendant le temps de midi juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
#
# Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ouai parffait > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:29 PM Subject: Re: images
# =ce serait bien de mettre ces photos la aussi
# Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila les photos, j'ai marqué a quoi ça correspondait en dessous
#
#
#
#
#
#    imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
#
# Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit :
#
# > **
# > ok ça marche
# >
# > ----- Original Message -----
# > *From:* etienne Turc <etienne.turc@gmail.com>
# > *To:* Valentin THIERRY <valenthierry@free.fr>
# > *Sent:* Monday, October 01, 2012 6:33 PM
# > *Subject:* Re: images
# >
# > eh je colle pas les images on voit sa demain pendant le temps de midi
# > juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
# >
# > Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
# >
# >> **
# >> ouai parffait
# >>
# >> ----- Original Message -----
# >> *From:* etienne Turc <etienne.turc@gmail.com>
# >> *To:* Valentin THIERRY <valenthierry@free.fr>
# >> *Sent:* Monday, October 01, 2012 6:29 PM
# >> *Subject:* Re: images
# >>
# >> =ce serait bien de mettre ces photos la aussi
# >>
# >> Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit
# >> :
# >>
# >>> **
# >>> voila les photos, j'ai marqué a quoi ça correspondait en dessous
# >>>
# >>
# >>
# >
#  imprime juste les 2 premières car moi j'ai plus d'encre pour tt imprimer
#
# Le 1 octobre 2012 18:48, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ok ça marche > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:33 PM Subject: Re: images
# eh je colle pas les images on voit sa demain pendant le temps de midi juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
#
# Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ouai parffait > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:29 PM Subject: Re: images
# =ce serait bien de mettre ces photos la aussi
# Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila les photos, j'ai marqué a quoi ça correspondait en dessous
#
#
#
#
#
#   eh je colle pas les images on voit sa demain pendant le temps de midi juste
# avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
#
# Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
#
# > **
# > ouai parffait
# >
# > ----- Original Message -----
# > *From:* etienne Turc <etienne.turc@gmail.com>
# > *To:* Valentin THIERRY <valenthierry@free.fr>
# > *Sent:* Monday, October 01, 2012 6:29 PM
# > *Subject:* Re: images
# >
# > =ce serait bien de mettre ces photos la aussi
# >
# > Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit :
# >
# >> **
# >> voila les photos, j'ai marqué a quoi ça correspondait en dessous
# >>
# >
# >
#  eh je colle pas les images on voit sa demain pendant le temps de midi juste avant de manger on a 10 min et 2 feuille suffise sinon j'imprime
#
# Le 1 octobre 2012 18:30, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ouai parffait > ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Monday, October 01, 2012 6:29 PM Subject: Re: images
# =ce serait bien de mettre ces photos la aussi
# Le 1 octobre 2012 18:25, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila les photos, j'ai marqué a quoi ça correspondait en dessous
#
#
#
#
#
#   envoi sur sa mail
#
# Le 29 septembre 2012 12:50, Valentin THIERRY <valenthierry@free.fr> a écrit
# :
#
# > **
# > ok, ben voila ce que j' ai fais, il faut encore que je finisse ma parti et
# > parler de gold coast
# > voici les liens
# >
# >
# >
# >
# >
# >
# > j'essaye de faire ma parti et de commencer celle de dino
# > JE ME CHARGE DU DIAPO
# > sinon est-ce que je l'envoie sur scolinfo ou sur son mail le dm de maths ?
# >
# > ----- Original Message -----
# > *From:* etienne Turc <etienne.turc@gmail.com>
# > *To:* Valentin THIERRY <valenthierry@free.fr>
# > *Sent:* Saturday, September 29, 2012 12:45 PM
# > *Subject:* Re:
# >
# > je vais pas pouvoir bosser cet après-midi car j’ai un match de basket
# > Dis moi ce que je dois faire en anglais et je le ferais demain ou ce soir
# >
# > Le 29 septembre 2012 12:33, Valentin THIERRY <valenthierry@free.fr> a
# > écrit :
# >
# >> **
# >> voila c'est le compte rendu fini
# >> il faut encore que je bose l'anglais dino a tjrs rien fais
# >>
# >> ----- Original Message -----
# >> *From:* etienne Turc <etienne.turc@gmail.com>
# >> *To:* valenthierry <valenthierry@free.fr>
# >> *Sent:* Saturday, September 29, 2012 10:52 AM
# >>
# >> j'ai mal au doigt.
# >> Envoi le truc pour le dm de maths au prof avec nos noms comme objet sinon
# >> bon week-end
# >>
# >>
# >
#  envoi sur sa mail
#
# Le 29 septembre 2012 12:50, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > ok, ben voila ce que j' ai fais, il faut encore que je finisse ma parti et parler de gold coastvoici les liens de faire ma parti et de commencer celle de dino JE ME CHARGE DU DIAPOsinon est-ce que je l'envoie sur scolinfo ou sur son mail le dm de maths ?> ----- Original Message ----- From: etienne Turc To: Valentin THIERRY Sent: Saturday, September 29, 2012 12:45 PM Subject: Re:
# je vais pas pouvoir bosser cet après-midi car j’ai un match de basket Dis moi ce que je dois faire en anglais et je le ferais demain ou ce soir
#
# Le 29 septembre 2012 12:33, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila c'est le compte rendu fini il faut encore que je bose l'anglais dino a tjrs rien fais > ----- Original Message ----- From: etienne Turc To: valenthierry Sent: Saturday, September 29, 2012 10:52 AM
# j'ai mal au doigt. Envoi le truc pour le dm de maths au prof avec nos noms comme objet sinon bon week-end
#
#
#
#
#
#   je vais pas pouvoir bosser cet après-midi car j’ai un match de basket
# Dis moi ce que je dois faire en anglais et je le ferais demain ou ce soir
#
# Le 29 septembre 2012 12:33, Valentin THIERRY <valenthierry@free.fr> a écrit
# :
#
# > **
# > voila c'est le compte rendu fini
# > il faut encore que je bose l'anglais dino a tjrs rien fais
# >
# > ----- Original Message -----
# > *From:* etienne Turc <etienne.turc@gmail.com>
# > *To:* valenthierry <valenthierry@free.fr>
# > *Sent:* Saturday, September 29, 2012 10:52 AM
# >
# > j'ai mal au doigt.
# > Envoi le truc pour le dm de maths au prof avec nos noms comme objet sinon
# > bon week-end
# >
# >
#  je vais pas pouvoir bosser cet après-midi car j’ai un match de basketDis moi ce que je dois faire en anglais et je le ferais demain ou ce soir
#
# Le 29 septembre 2012 12:33, Valentin THIERRY <valenthierry@free.fr> a écrit :
# > voila c'est le compte rendu finiil faut encore que je bose l'anglais dino a tjrs rien fais> ----- Original Message ----- From: etienne Turc To: valenthierry Sent: Saturday, September 29, 2012 10:52 AM
# j'ai mal au doigt. Envoi le truc pour le dm de maths au prof avec nos noms comme objet sinon bon week-end
#
#
#
#
#
#   Ce serait bien de faire sur le football australien est sur le criquet et de
# faire une intro sur le sport en australie.
#  Ce serait bien de faire sur le football australien est sur le criquet et de faire une intro sur le sport en australie.
