# %%
import pandas as pd

from utils import tag_mail

# %%
df = pd.read_json(r'data/gmail_azoulai_basic.txt', encoding = 'utf-8')

# %%
df['cat'] = df.headers.apply(tag_mail)

df.loc[df.cat=='amazon']
# Out:
#                                                 snippet                date  \
# 366   Bonjour azoulai, Votre colis contenant ELEGOO ... 2019-10-20 07:05:45
# 367   Bonjour azoulai, Votre colis contenant ELEGOO ... 2019-10-20 07:03:21
# 368   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-10-19 23:49:02
# 369   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-10-19 08:46:41
# 370   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-10-18 18:37:34
# 794   Votre abonnement de un an démarre maintenant A... 2019-05-26 13:49:54
# 824   Merci d&#39;avoir visité Amazon.fr ! À votre d... 2019-05-16 18:34:55
# 825   Aide sur le mot de passe Pour vérifier votre i... 2019-05-16 18:33:00
# 862   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-04-29 22:52:37
# 864   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:52:04
# 865   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:51:11
# ...

# %%
import re
df_amazon = df.loc[df.cat=='amazon']

df_amazon = df_amazon.loc[df_amazon.body.str.contains("Votre Expédition ")]

for el in df.body:
    
    try:
        cost = re.findall(r'Montant total pour cet envoi : EUR \d{0,100000},\d\d', el)[0]
    except:
        continue
        
    try:
        payement_tool = re.findall(r'Payé par (.*?): ', el)[0]
    except:
        payement_tool = ''
    
    print(re.findall(r'\(Vendu par (.*?) EUR \d{0,100000},\d\d', el, re.DOTALL)) # 
    
    
#     print(el)
    print('\n\n')
    print('#######################################################')
    print('\n\n')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-73-b4e8b32b72cb> in <module>
#      16         payement_tool = ''
#      17
# ---> 18     print(re.findall(r'(?s)\(Vendu par (.*?) ((?!(\r?\n){2}).)*+', el, re.DOTALL)) # \(Vendu par (.*?) EUR \d{0,100000},\d\d
#      19
#      20
#
# ~\Anaconda3\lib\re.py in findall(pattern, string, flags)
#     221
#     222     Empty matches are included in the result."""
# --> 223     return _compile(pattern, flags).findall(string)
#     224
#     225 def finditer(pattern, string, flags=0):
#
# ~\Anaconda3\lib\re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
#     287     if not (flags & DEBUG):
#     288         if len(_cache) >= _MAXCACHE:
#
# ...
