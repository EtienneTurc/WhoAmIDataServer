# %%
import pandas as pd
import numpy as np

import re

from utils import tag_mail

# %%
df = pd.read_json(r'data/gmail_boetto_basic.txt', encoding = 'utf-8')

# %%
df['cat'] = df.headers.apply(tag_mail)

df.loc[df.cat=='sncf']
# Out:
#                                                 snippet                date  \
# 1228  Doctolib RDV confirmé Clinique Ostéopathique d... 2018-11-21 16:45:29
# 1869  Doctolib Rappel : vous avez un rendez-vous dem... 2017-01-01 14:25:31
# 1870  Doctolib Rappel : vous avez un rendez-vous le ... 2016-12-26 14:27:32
# 1875  Doctolib Votre rendez-vous du lundi 02 janvier... 2016-12-22 10:58:22
#
#                                                 headers  \
# 1228  [{'name': 'From', 'value': 'Doctolib <no-reply...
# 1869  [{'name': 'From', 'value': 'Doctolib <julia@do...
# 1870  [{'name': 'From', 'value': 'Doctolib <julia@do...
# 1875  [{'name': 'From', 'value': 'Doctolib <julia@do...
#
#                                                    body       cat
# 1228                                                     doctolib
# 1869   DoctolibVotre rendez-vousVotre rendez-vous \n...  doctolib
# 1870   DoctolibVotre rendez-vousVotre rendez-vous \n...  doctolib
# 1875   DoctolibVotre rendez-vousVotre rendez-vous \n...  doctolib

# %%
mails_sncf = df.loc[df.cat == 'sncf']

for el in mails_sncf.body:
    print(el)
    print('\n\n')
    print('#####################################################')
    print('\n\n')
# Out:
#  Prenez de l'avance avec OUIGO !
#
# Anticipez les beaux jours à 20€ et moins.
# Avec OUIGO, la réservation est déjà possible pour des voyages jusqu'au 3 juillet 2020.
#
#
#
#
#
#
# #####################################################
#
#
#
#  Vos privilèges avec votre carte
#
# Partez en week-end ou en vacances régulièrement !
# Grâce à votre carte Avantage vous faites des économies en bénéficiant de -30% (1) toute l'année sur TGV INOUI, INTERCITÉS et des transporteurs internationaux.
#
# Je réserve
# >>>>
#
#
# ------------------------------------------------
# (1)Offre réservée à l'ensemble des titulaires de cartes Avantage, et un accompagnateur de plus de 12 ans pour les titulaires de la carte Avantage Week-end ou Famille. Réduction calculée, hors prestations supplémentaires payantes, sur le tarif PREM'S, SECONDE, PREMIERE et le Plein Tarif SECONDE et PREMIERE pour les trains à réservation obligatoire (TGV INOUI et INTERCITÉS, hors OUIGO et INTERCITÉS 100% ECO).
# Réductions applicables sur le territoire national (sauf trajets effectués intégralement en IDF). Dans les trains TGV INOUI et les trains INTERCITÉS la carte permet de bénéficier d'une réduction de 30% calculée sur le tarif SECONDE et PREMIERE et d'une réduction de 30% sur le Tarif Normal pour les trains INTERCITÉS sans réservation obligatoire dans le cadre de billets valables 7 jours.
# Dans les TER, la carte permet de bénéficier d'une réduction de 25% garantis toute l'année sous réserve qu'elle soit acceptée par l'autorité organisatrice des transports régionaux sur son périmètre (et jusqu'à 50% selon les règles d'application du calendrier voyageurs par les régions). Information disponible sur les sites régionaux TER. Réduction calculée, hors prestations supplémentaires payantes, sur le tarif SECONDE ou PREMIERE du jour sur les trains TGV INOUI à destination du Luxembourg, de Fribourg-en-Brisgau et sur les trains TGV INOUI et ICE de DB-SNCF en coopération ; sur le tarif SECONDA ou PRIMA (Seconde ou Première) du jour sur les TGV France-Italie ; sur le tarif STANDARD ou STANDARD 1re des trains TGV Lyria et sur le tarif Flexi ou Essential du jour des trains de Renfe-SNCF en coopération.
# Offre valable pour un accompagnateur pour les titulaires de la carte Avantage Week-end ou Famille (uniquement valable pour la carte Avantage Week-end pour Renfe-SNCF en coopération).
#
#
#
#
# #####################################################
#
#
#
#  Châteaux, nature, paysages, activités... Direction l'Allemagne
#
# Découvrez l’Allemagne autrement
# Partez en Allemagne depuis Paris à partir de 33 €/AS* et depuis Lyon à partir de 50 €/AS*
# >>>>>
#
#
#
# Top 10 des plus
# beaux châteaux
# Réveillez l'enfant qui sommeille
# en vous et découvrez des
# châteaux qui font rêver
# Je découvre
# >>>>>
#
#
#
#
# City-trip en famille :
# les activités à faire
# Les villes allemandes savent
# faire plaisir aux enfants sans
# oublier leurs parents
# Je découvre
# >>>>>
#
#
#
# 5 activités nature à découvrir
# au cœur de l'Allemagne
# Mettez-vous au vert et
# découvrez les plus beaux
# paysages allemands
# Je découvre
# >>>>>
#
#
# ----------------------------------------------------------------------------------------
#
#
#
#
# #####################################################
#
#
#
#  Bientôt la fête des grands-mères
#
# Le week-end prochain, c'est la fête des grands-mères ! Pour cette occasion achetez votre billet de train et partez partager des moments en famille.
#
# J'y vais >>>>>
#
#
#
#
# #####################################################
#
#
#
#  Faites voyager vos enfants à petits prix
#
# Pendant les vacances, faites une escapade en famille, les billets INTERCITÉS
# sont à 5€(1) pour les enfants de moins de 12 ans. Clermont-Ferrand, Limoges, Bordeaux...
# Vous avez le choix ! Vite, l'offre est à saisir jusqu'à jeudi pour des voyages du 18 février au 01 mars 2020.
#
# Tous les billets enfants à 5€ /AS(1)
#
# J'en profite
#
#
#
#
#
# #####################################################
#
#
#
#  C'est le moment de partir... Retrouvez le meilleur prix en quelques clics pour votre trajet préféré, grâce au calendrier des prix !
#
# >
# ------------------------------------
#
#
#
#
# #####################################################
#
#
#
# Découvrez les villes tendances de 2020Pour visualiser correctement cette lettre d'information, consultez la version en ligne.L'Europe à prix promoDécouvrez l'Europe à grande vitesse avec TGV INOUI ! Flânez dans les rues de Barcelone. Buvez un café chaud à Genève. Visitez les sites historiques de Luxembourg ou de Fribourg-en-Brisgau.Dès 29€/AS(1)J'en profiteGenève Au départ de Paris - 3h11*Dès 29€ (1) A/SJe réserveFribourg-en-Brisgau Au départ de Paris - 3h05*Dès 29€ (1) A/SJe réserveBarcelone Au départ de Paris - 6h27*Dès 29€ (1) A/SJe réserveBruxelles Au départ de Lyon - 3h43*Dès 29€ (1) A/SJe réserveTurin Au départ de Paris - 5h34*Dès 29€ (1) A/SJe réserveFrancfort Au départ de Paris - 3h38*Dès 29€ (1) A/SJe réserveJe fais mes bagages !OUI.sncf est le distributeur de voyages en ligne de la SNCF sur la France et l'Europe :
# préparez vos voyages, réservez vos billets de train.
#
# Vous avez des choses à nous dire ?
# Nos conseillers sont là 24h/24, 7jours sur 7 par téléphone, t’chat, email ou sur les réseaux sociaux.Réservez, échangez ou annulez vos billets de train depuis votre mobile ou tabletteComparez les prix de nos billets de train et trouvez celui qui vous convientSi vous ne souhaitez plus recevoir d’emails de la part de OUI.sncf, vous pouvez vous désabonner en cliquant iciPour vous assurer de recevoir notre newsletter, nous vous recommandons d'ajouter l'adressebonsplans@newsletter.oui.sncf à vos contacts.(1) Prix TTC par personne, à partir de, pour un aller simple en seconde classe effectué avec Renfe - SNCF en coopération, DB - SNCF en coopération, TGV Lyria, TGV INOUI vers l'Italie, Bruxelles, Fribourg-en-Brisgau et le Luxembourg, certains jours et dans certains trains, sur une sélection de destinations en Europe depuis la France, hors acheminement depuis les gares des lignes desservant les destinations. Billets en vente du 4 au 11 février2020 inclus, pour des voyages effectués entre le 8 février et le 31 mai 2020 inclus selon la destination, dans la limite des places disponibles à ce tarif.
# Billets non échangeables et non remboursables. Offre non cumulable avec toute autre promotion en cours ou tarif réduit SNCF.
# TGV INOUI est une marque déposée de SNCF Mobilités. Tous droits de reproduction réservés.
# *Meilleur temps de parcours
# En ouvrant cet email, vous acceptez le dépôt de nos cookies et ceux de nos partenaires a des fins de personnalisation d'annonces commerciales, de mesure ou d'analyse.Pour en savoir plus ou les configurer, suivez cette page.
# Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 € - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière :APS - R.C. : GAN - Récépissé CNIL n° 745549
#
#
#
# #####################################################
#
#
#
#  Voyagez à petits prix
#
# En ville, à la mer, ou à la montagne, les trains INTERCITÉS vous transportent
# partout en France vers plus de 200 destinations.
#
#
#
#
#
#
# #####################################################
#
#
#
#  L'Europe à prix promo
#
# Découvrez l'Europe à grande vitesse avec TGV INOUI ! Flânez dans les rues de Barcelone. Buvez un café chaud à Genève. Visitez les sites historiques de Luxembourg ou de Fribourg-en-Brisgau.
# Dès 29€ /AS(1)
# J'en profite
#
#
#
#
#
#
# #####################################################
#
#
#
#  Votre carte Avantage vous offre plus que ce que vous ne pensez&hellip;
#
#  Si vous ne visualisez pas cet email,
#
# cliquez ici
#
#
# Christophe Boetto
# Carte expirant le 11/08/2020
#
# Monsieur BOETTO,
#
#
# C'est bientôt les vacances et vous voulez partir l’esprit tranquille ? Grâce à votre carte Avantage, vous pouvez profiter de réductions sur les services TGV INOUI avant, pendant et après votre voyage.
#
#
# DES AVANTAGES ADAPTÉS À TOUTES LES SITUATIONS
#
#
# Trop de bagages ?
#
#
#
#  -15%
#
#  sur la commande(1)
#
#
#  pour voyager les mains libres et l’esprit léger !
#
#
#
# > En savoir plus
#
# Une petite faim ?
#
#
#
#  -15%
#
#  sur la restauration
# à bord(2)
#
#
#  pour se laisser surprendre par des recettes savoureuses et des produits inédits.
#
#
#
# > En savoir plus
#
# Une voiture à l’arrivée ?
#
#
#
#  -15%(3)
#
#
#  en réservant ma location AVIS avec mon billet de train.
#
#
#
# > En savoir plus
#
#
#
#
#  SNCF
#
#
#  (1) Délai de livraison dès le lendemain valable pour le transport de bagages en provenance et à destination du territoire français continental, ainsi que les îles de Ré, Noirmoutier et Oléron, qui sont accessibles par la route sous réserve d’un enlèvement avant 17h et hors département 05, 06, 73 et 74 pour lesquels la livraison ne peut être effectuée que le surlendemain de l’enlèvement.
#
# Chaque bagage ordinaire (maximum 9 par commande) ou volumineux (maximum 9 par commande) ne doit pas dépasser 25 kg. Est considéré volumineux tout bagage dont la somme des trois dimensions est supérieure à 2,50 m. Prix en vigueur au 01/01/2019, 38€ le premier bagage ordinaire puis 15€ les suivants pour les membres du programme de fidélité SNCF,90€ par bagage volumineux ou par vélo, 30€ pour un fauteuil roulant sans moteur.
#
#
#
# (2) L’offre de 15% s’applique aussi sur certains menus de la Restauration à bord INTERCITÉS. Offres soumises à conditions. Informations disponibles sur sncf.com.
#
#
#  (3) La remise de clés s’effectue par un agent SNCF en dehors des horaires d’ouverture de l’agence AVIS. Conditions de l’offre Ma Location AVIS® sur
#
#  .
#
#
#
#  Si vous souhaitez vous désinscrire et ne plus recevoir de communications commerciales de la part de SNCF Mobilités et CRMServices, cliquez
#
# ici .
#
#  Cette communication vous est envoyée par CRMServices, filiale de SNCF Voyageur en charge du programme de fidélité de cette dernière, au titre de l’ « exception des produits et services analogues » (article L. 34-5 du Code des postes et des communications électroniques) - SAS au capital de 500 000 euros - RCS Nanterre B 477 909 436 - 2 place de la Défense - CNIT 1 - BP440 - 92053 Paris La Défense Cedex.
#
#
#  Vous disposez à tout moment d’un droit d’accès, de rectification, de limitation, de portabilité, de suppression, d’opposition de vos données personnelles (ainsi que du droit de définir les directives applicable à la conservation, l’effacement et la communication de celles-ci après votre décès) en contactant notre Délégué à la Protection des Données par e-mail (
# mailto:donneespersonnellesvoyages@sncf.fr
# donneespersonnellesvoyages@sncf.fr ) ou par courrier à l’adresse suivante :
#
# SNCF Voyageur – Délégué à la Protection des Données - 9, rue Jean-Philippe Rameau – 93210 Saint Denis - France. Vous disposez également du droit de définir des directives relatives à la conservation, à l’effacement et à la communication de vos données personnelles après votre décès, conformément au cadre juridique applicable.
#
# En cas de réclamation, vous pouvez contacter le délégué à la protection des données personnelles (aux coordonnées indiquées ci-dessus). Vous disposez également du droit d’introduire une réclamation auprès d’une autorité de contrôle (CNIL).
#
# Vous trouverez plus d’informations concernant le traitement de vos données à caractère personnel, en consultant nos conditions générales d’utilisation.
#
#
#  Ce message est envoyé par un automate, merci de ne pas y répondre. Votre réponse ne pourra être traitée.
#
#
#  2002_PT_AV_BOOST_SERVICE
#
#
#
#
#
#
# #####################################################
#
#
#
#  Bon Plan du moment
# Découvrez le nouveau réseau NOMAD entre Paris et la Normandie et profitez des petits prix
# Dès 10E /AS(1)
# Je fonce >>>>
#
#
# Rouen
# Au départ de Paris
# Dès 10E(1)/AS
# >>>>
#
#
# Caen
# Au départ de Paris
# Dès 15E(1)/AS
# >>>>
#
#
# Trouville/Deauville
# Au départ de Paris
# Dès 15E(1)/AS
# >>>>
#
#
# Le Havre
# Au départ de Paris
# Dès 15E(1)/AS
# >>>>
#
#
# Envie d’une escapade parisienne ?
#
# La capitale encore plus proche
# Au départ du Havre, Caen, Trouville/Deauville, Rouen et d'autres gares normandes !
# Dès 10E (1) /Aller
# >>>>
#
#
# --------------------------------------
# (1) Tarif TTC à partir de et par personne, pour un aller simple, en 2nde classe. Offre soumise à conditions et sous réserve de disponibilité.
#
#
#
#
# #####################################################
#
#
#
#  C'est le moment de partir... Retrouvez le meilleur prix en quelques clics pour votre trajet préféré, grâce au calendrier des prix !
#
# >
# ------------------------------------
#
#
#
#
# #####################################################
#
#
#
#  Grâce à votre carte Avantage, vous bénéficiez d'un code Avantage de -30%(1).
#
#  Si vous ne visualisez pas cet email,
#
# cliquez ici
#
#
# Christophe Boetto
# Carte expirant le 11/08/2020
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Monsieur BOETTO,
#
#
# Vous avez subi une grève d’une durée exceptionnelle. Je le regrette vivement et vous présente, au nom de SNCF, toutes mes excuses.
#
#
#
# La période des fêtes est un moment privilégié où les familles se retrouvent et nous n’avons eu qu’un seul objectif : réduire au maximum l’impact du conflit sur votre vie et permettre au maximum d’entre vous de voyager. Nos ressources disponibles ont été mobilisées à dessein pour faire circuler le plus grand nombre de trains.
#
#
#
# Malgré tous nos moyens mis en œuvre pour que vous puissiez vous organiser au mieux, la grève a pénalisé vos déplacements.
#
#
#
# Afin de vous remercier de votre patience et conserver votre confiance, nous vous avons réservé une attention particulière : une réduction de 30%(1) sur votre prochain trajet, cumulable avec votre carte Avantage. De plus, 5 millions de billets à moins de 35 euros vous seront également proposés du 23 au 30 janvier.
#
#
#
# Aujourd’hui, toutes les circulations et destinations sont rétablies, vous pouvez désormais voyager sereinement sur l’ensemble des trains TGV INOUI.
#
#
#  Nous espérons vous retrouver très prochainement dans nos trains.
#
#
#
# Rachel Picard, Directrice Générale de Voyages SNCF.
#
#
#
#
#  AVEC LE CODE AVANTAGE
#
#
#  DCNACD5
#
#
#
#  Valable jusqu'au 09/03/2020
#
#
#
#
#
#
#
#
#
#
#
#
# > J'en profite
#
#
# > Comment utiliser mon code Avantage
#
#
#
#
#
#
#
#  SNCF
#
#
#  (1) Ce code Avantage est valable jusqu'au 09 mars 2020 inclus. Vous pouvez le retrouver dans cet email ou dans votre espace personnel du site Programme Voyageur, espace "Mes cartes et bons d'achat". Il est exclusivement applicable pour l'achat d'un billet de train SNCF à réservation obligatoire (hors TER, Transilien et OUIGO) sur un parcours en France métropolitaine aux tarifs Loisir (Tarif Normal, Loisir réduit, Loisir Week-end et plein tarif Loisir), Pro (Business Première, INTERCITÉS Pro, tarifs Fréquence et Liberté, tarifs négociés) ou pour l'achat d'un billet éligible à l'application des réductions octroyées par les cartes de réduction SNCF (Enfant+, Jeune, Week-End et Senior+) ou les cartes Avantage. Ce code Avantage n'est pas cumulable avec tout autre code Avantage ou code
#  promotionnel, de quelque nature que ce soit (autre code Avantage, code promotionnel, code de réduction, etc). Il n'est pas non plus cumulable avec les offres promotionnelles. Pour un trajet aller-retour, le code Avantage s'applique au premier trajet respectant les conditions d'utilisation décrites. Si vous souhaitez que le code Avantage soit appliqué sur le trajet retour, vous devez effectuer une commande distincte pour l'aller et le retour. Pour un trajet simple, comprenant une ou plusieurs correspondances, dont l'une ne répond pas aux conditions d'utilisation décrites, le code Avantage ne peut pas être utilisé. Les conditions d'échange et de remboursement des billets achetés avec un code Avantage sont celles applicables au tarif choisi. Dans le cas d'un échange, le bénéfice du code
#  Avantage est conservé si le nouveau tarif choisi correspond aux conditions précitées et si le code Avantage est toujours valide au moment de l'échange. En cas de remboursement, le code n'est plus valable. L'échange des billets achetés avec un code Avantage sur les Bornes Libre-Service fait perdre le code Avantage. Il est valable en gares (hors Bornes Libre-Service), boutiques SNCF, agences de voyages agréées SNCF, sur internet et par téléphone au 3635 (service gratuit + prix appel) ou si vous êtes membre Grand Voyageur, Grand Voyageur Plus ou Grand Voyageur Le Club du Programme Voyageur au 0 808 808 330 (service gratuit + prix appel).
#
#
# Si vous souhaitez vous désinscrire et ne plus recevoir de communications commerciales de la part de SNCF Mobilités et CRMServices,
#
# cliquez ici.
#
#
#  Cette communication vous est envoyée par CRMServices, filiale de SNCF Voyageur en charge du programme de fidélité de cette dernière, au titre de l’ « exception des produits et services analogues » (article L. 34-5 du Code des postes et des communications électroniques) - SAS au capital de 500 000 euros - RCS Nanterre B 477 909 436 - 2 place de la Défense - CNIT 1 - BP440 - 92053 Paris La Défense Cedex.
#
#
#  Vous disposez à tout moment d’un droit d’accès, de rectification, de limitation, de portabilité, de suppression, d’opposition de vos données personnelles (ainsi que du droit de définir les directives applicable à la conservation, l’effacement et la communication de celles-ci après votre décès) en contactant notre Délégué à la Protection des Données par e-mail (
# mailto:donneespersonnellesvoyages@sncf.fr
# donneespersonnellesvoyages@sncf.fr ) ou par courrier à l’adresse suivante :
#
# SNCF Voyageur – Délégué à la Protection des Données - 9, rue Jean-Philippe Rameau – 93210 Saint Denis - France. Vous disposez également du droit de définir des directives relatives à la conservation, à l’effacement et à la communication de vos données personnelles après votre décès, conformément au cadre juridique applicable.
#
# En cas de réclamation, vous pouvez contacter le délégué à la protection des données personnelles (aux coordonnées indiquées ci-dessus). Vous disposez également du droit d’introduire une réclamation auprès d’une autorité de contrôle (CNIL).
#
# Vous trouverez plus d’informations concernant le traitement de vos données à caractère personnel, en consultant l’article […] de nos conditions générales d’utilisation.
#
#
#  Ce message est envoyé par un automate, merci de ne pas y répondre. Votre réponse ne pourra être traitée.
#
#
#  2001_PT_AV_RECOV30
#
#
#
#
#
#
# #####################################################
#
#
#
#  Cap sur les vacances
#
# C'est le moment de fermer les cahiers, les ordinateurs et de faire sa valise ;)
# Bons plans du moment, inspirations voyages... nous avons pensé à vous.
#
# >>>>
#
#
#
#
#
# #####################################################
#
#
#
#  Plus de 5 millions de billets à 35€ max(1)
# Profitez de prix exceptionnels pour bien démarrer l’année !
# Soyez les premiers : réservez vos billets de train avec TGV INOUI, OUIGO et INTERCITÉS
# à tous petits prix jusqu'au 30 janvier pour des voyages du 23 janvier au 15 avril.
#
#
#
#
#
#
# #####################################################
#
#
#
#  Cupidon vous emmène à Strasbourg
#
# Vous voulez séduire votre moitié ? Venez fêter votre Saint-Valentin du 8 au 16 février à Strasbourg pendant l'événement "Strasbourg mon amour"…
#
# Avec TGV INOUI partez à 2, payez pour 1 (1) !
# Réservez jusqu'au 25 janvier pour des voyages du 8 février au 31 mars inclus.
#
# Je l'emmène !
# >>>>
#
#
# --------------------------------------------------------------
# (1) Offre valable pour deux personnes voyageant ensemble à bord du même train et de la même classe. Les billets doivent être achetés au moyen d'une seule commande et d'un seul paiement. Réduction appliquée sur le tarif Loisir à la date de l'achat et répartie de façon égale sur les deux billets établis au même prix.
# Offre valable pour un aller simple sans correspondance en 1ère et 2nde classe dans les TGV INOUI (hors OUIGO), sur une sélection de destinations en France, certains jours et dans certains trains, dans la limite des places disponibles à ce tarif. Billets en vente du 21 au 25 janvier 2020 inclus, pour des voyages du 8 février au 31 mars 2020 inclus.
# Billets non échangeables, non remboursables. Offre non cumulable avec toute autre promotion en cours, code avantage ou tarif réduit SNCF. Paiement en ligne obligatoire avec billet à imprimer soi-même, envoi gratuit du billet à domicile, retrait en borne libre service en gares françaises, ou en boutique SNCF Rail Europe (frais de 10 euros par référence de dossier)
#
#
#
#
# #####################################################
#
#
#
#  Nouveau avec OUIGO
#
# Nîmes et Montpellier sont désormais accessibles avec OUIGO au départ ou à destination de Paris Gare de Lyonsitué au centre de Paris.
# Dès 19euros/AS(1)
# >>>>
#
#
# ------------------------------------------------
# (1)Prix TTC par adulte et 8E par enfant, valables sur les trajets de Paris Gare de Lyon – Nîmes, Nîmes – Paris Gare de Lyon et Paris Gare de Lyon – Montpellier, Montpellier – Paris Gare de Lyon dans la limite des places disponibles à ce tarif sur les trains éligibles.
# Billets en vente du 20/01 au 02/02 inclus pour des voyages du 20/01/2020 au 03/07/2020 inclus pour un aller simple effectué en OUIGO. Offre valable jusqu'à épuisement du nombre de billets disponibles à ce prix. Offre non cumulable avec toute autre promotion en cours.
#
#
#
#
# #####################################################
#
#
#
#  Le printemps se prépare en janvier
# Réservez vos billets de train avec TGV INOUI et INTERCITÉS(1) pour les vacances de printemps, Pâques et les ponts du 1er et 8 mai.
# Allez même un peu plus loin avec OUIGO(2), déjà ouvert jusqu'au 3 juillet 2020.
# La belle saison s'organise maintenant !
#
#
# Je réserve
#
#
#
#
# #####################################################
#
#
#
#  On en voit plus quand on ne vole pas
#
# Jusqu'au 20 janvier, profitez de notre promo Eurostar et partez à la découverte de Londres à prix mini !
# Dès 34€ /AS(1)
# J'en profite
#
#
#
#
#
# #####################################################
#
#
#
#  ENVOI REMARKETING
#
#
#
#
# #####################################################
#
#
#
#  Bonjour,
#
# Nous sommes heureux de vous informer que votre train 6174 circulera bien comme prévu le 30/12/2019, malgré le mouvement de grève national.
#
# Cette confirmation concerne uniquement votre voyage sur le train 6174. Si vous avez des correspondances TER, nous vous invitons à vérifier leurs circulations sur le site sncf.com [ ] à partir de 17h, la veille de votre voyage.
#
# Les équipes SNCF sont actuellement mobilisées pour limiter au maximum les désagréments que vous pourriez rencontrer sur cette période.
#
# Les informations en temps réel sont disponibles sur l’application l’Assistant SNCF , le site sncf.com et par téléphone au 36 35 (appel sans surcout).
#
#
# Vous pouvez également solliciter l’agent virtuel SNCF sur SNCF Messenger et sur SNCF Tweeter .
#
#  Vous pouvez compter sur notre engagement à vos côtés.
#
# L’équipe SNCF
#
#
# ----------------------------------------------------
# Hello,
#
#
# We'd like to confirm your train 6174 on 30/12/2019 will run as scheduled. The SNCF rail strike will not affect your train journey.
#
# Before departure, check out details about how our services are running and be informed on any disruption on your journey on:
# - SNCF.com website under the timetables and live traffic updates section
# - Assistant SNCF or OUI.sncf mobile apps
# - By calling 00 33 1 84 94 36 35 (cost of international call + fees of your phone operator) or at your original selling point
#
# Have a pleasant journey.
#
#
#
#
# #####################################################
#
#
#
# Pour visualiser correctement cette lettre d'information, consultez la version en ligne.Chère cliente, cher client, En raison d’une grève nationale interprofessionnelle depuis le 05/12, le trafic SNCF est fortement réduit sur l’ensemble du réseau. Si vous avez prévu de voyager au cours du mois, plusieurs options s'offrent à vous.Vous souhaitez conserver votre billet Rendez-vous sur OUI.sncf afin de vérifier les conditions de circulation de votre train. Je m'informeVous préférez l'annuler ou l'échanger Faites-le directement en ligne sur OUI.sncf. Aucuns frais ne seront appliqués*.J'y vais*L’absence de frais n’est mentionnée qu’à la fin de votre échange ou annulation. Rassurez-vous, la suppression ou l’annulation de votre billet initial ne sont effectives qu’après votre validation finale.Echangez votre billet en quelques clicsPensez bien à aller jusqu’au bout de votre demande1J’importe mon billet2Je sélectionne « Voir mon voyage »3Je clique sur « Echanger mon billet » et je me laisse guider4Je modifie les informations de voyage5Je valide mon nouveau voyage6Je renseigne mon adresse mail et reçois un mail de confirmationJ'échange mon billetOUI.sncf est le distributeur de voyages en ligne de la SNCF sur la France et l'Europe :
# préparez vos voyages, réservez vos billets de train.
#
# Vous avez des choses à nous dire ?
# Nos conseillers sont là 24h/24, 7jours sur 7 par téléphone, t’chat, email ou sur les réseaux sociaux.Réservez, échangez ou annulez vos billets de train depuis votre mobile ou tabletteComparez les prix de nos billets de train et trouvez celui qui vous convientSi vous ne souhaitez plus recevoir d’emails de la part de OUI.sncf, vous pouvez vous désabonner en cliquant iciPour vous assurer de recevoir notre newsletter, nous vous recommandons d'ajouter l'adressebonsplans@newsletter.oui.sncf à vos contacts.En ouvrant cet email, vous acceptez le dépôt de nos cookies et ceux de nos partenaires a des fins de personnalisation d'annonces commerciales, de mesure ou d'analyse.Pour en savoir plus ou les configurer, suivez cette page.
# Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 € - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière :APS - R.C. : GAN - Récépissé CNIL n° 745549
#
#
#
# #####################################################
#
#
#
#  Bonjour,
#
# Nous sommes heureux de vous informer que votre train 6155 circulera bien comme prévu le 25/12/2019, malgré la grève nationale interprofessionnelle.
#
# Cette confirmation concerne uniquement votre voyage sur le train 6155. Si vous avez des correspondances TER, nous vous invitons à vérifier leurs circulations sur le site sncf.com [ ] à partir de 17h, la veille de votre voyage.
#
# Les équipes SNCF sont actuellement mobilisées pour limiter au maximum les désagréments que vous pourriez rencontrer sur cette période.
#
# Les informations en temps réel sont disponibles sur l’application l’Assistant SNCF , le site sncf.com et par téléphone au 36 35 (appel sans surcout).
#
#
# L’agent virtuel SNCF est à votre disposition sur SNCF Messenger et sur SNCF Twitter .
#
#  Vous pouvez compter sur notre engagement à vos côtés.
#
# L’équipe SNCF
#
#
# ----------------------------------------------------
# Hello,
#
#
# We'd like to confirm your train 6155 on 25/12/2019 will run as scheduled. The SNCF rail strike will not affect your train journey.
#
# Before departure, check out details about how our services are running and be informed on any disruption on your journey on:
# - SNCF.com website under the timetables and live traffic updates section
# - Assistant SNCF or OUI.sncf mobile apps
# - By calling 00 33 1 84 94 36 35 (cost of international call + fees of your phone operator) or at your original selling point
#
# Have a pleasant journey.
#
#
#
#
# #####################################################
#
#
#
#  OUI.SNCF
#
# MERCI ET BON VOYAGE
#
#
# Votre billet est nominatif et à usage strictement personnel.
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
# VOTRE RÉSERVATION
# - - - - - - - - - - - - - - - - - - - - - - -
#
# - Aller MARSEILLE SAINT CHARLES - PARIS GARE DE LYON 81,00 €
# - Référence : SMFPUU- Voyageur : Christophe Boetto
# - Nom : Boetto
# - Mode de retrait : Mon e-billet
#
# Votre e-billet est directement embarqué dans votre carte de fidélité.
# Pour avoir plus de détails sur votre réservation, rendez-vous sur votre espaceMon Voyage
#
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
# VOTRE VOYAGE
# - - - - - - - - - - - - - - - - - - - - - - -
# ALLER Lundi 30 décembre 2019
# - Départ à 12h49 de MARSEILLE SAINT CHARLES
#  TGV INOUI n° 6174 | 2nde classe
#  Voiture 8 Place 85
#  3h11
#  Services à bord : Wifi - Personne à mobilité réduite - Bar -
#  Arrivée à 16h00 à PARIS GARE DE LYON
#
#
#
#
#
#
#
#
#
#
# Les détenteurs de carte de fidélité retrouveront leur e-billet enregistré directement dans leur carte de fidélité et dans son code-barre dans leur mobile. Le jour du voyage, pas besoin de composter votre billet, prenez place directement dans le train. En cas d'oubli, ou de problème d'impression, vous pouvez retirer en Borne Libre Service.
#
# Munissez-vous de votre Carte Voyageur en cours de validité.
# L'accès au quai ferme 2 minutes avant le départ du train. Une pièce d'identité peut vous être demandée lors du contrôle dans le train.
#
#
# L'étiquetage des bagages est obligatoire.
#
#
#
#
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
# DETAIL DES PASSAGERS
# - - - - - - - - - - - - - - - - - - - - - - -
# - Christophe Boetto (12-25 ans)
#  - ALLER BILLET CARTE JEUNE
#  Carte Jeune en cours de validité à présenter à bord du train. Billet échangeable et remboursable sans frais à l'émission du billet puis avec des frais de 5 &euro; la veille et le jour du départ. À partir de 30 minutes avant départ du train, billet échangeable 2 fois maximum uniquement pour le même jour et le même trajet et non remboursable après échange. A ces frais s'ajoute l'éventuelle différence de prix entre l'ancien et le nouveau billet. Billet non échangeable et non remboursable après le départ.
#  Votre code avantage a bien été pris en compte.
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
# RÉCAPITULATIF DE PAIEMENT
# - - - - - - - - - - - - - - - - - - - - - - -
#
# - Paiement accepté avec la carte VISA n° ############570#
# - Vente à distance sécurisée
#
# - Vos billets : 81,00 €
# - Vos billets : 81,00 €
# - Transaction n° 831331 SNCF 055204944722240 : 81,00 €
# - Effectué le 06 décembre 2019 à 18:20
# - Autorisation n° 443785
# - Effectué en mode 3DS - Verified By Visa
#
#
#
#
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
# OUI.SNCF
#
# OUI.sncf - 2 place de la Défense, CNIT 1, BP 440, 92053 Paris La Défense Cedex - - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 € - Licence d'agence de voyages n° LI 092 01 0002 - - Garantie financière : APS - R.C : GAN - Récépissé CNIL 745549
#
# L'Agence OUI.sncf - 2 place de la Défense, CNIT 1, BP 440, 92053 Paris La Défense Cedex - - RCS Nanterre B 439 202 078 - S.A.S au capital de 3.000.000 € - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière : APS - R.C : GAN - Récépissé CNIL 776624
#
# Nous vous conseillons d'imprimer cette page afin de conserver les différentes références de votre commande. Ce mail ne peut en aucun cas remplacer un titre de transport.Merci de ne pas répondre directement à ce mail de confirmation, votre message ne serait pas traité.Pour vous assurer de recevoir nos e-mails de confirmation d'achat, nous vous recommandons d'ajouter l'adresse noreply@oui.sncf à votre carnet d'adresses.
#
#
#
#
#
# #####################################################
#
#
#
# Pour visualiser correctement cette lettre d'information, consultez la version en ligne.Le trafic SNCF sera fortement perturbé sur l’ensemble du réseau du 7 au 9 décembre 2019 en raison d’une grève nationale interprofessionnelle. Nous vous invitons à vérifier les conditions de circulation avant de vous rendre en gare. Les trains dont la circulation est confirmée sont d’ores et déjà visibles sur OUI.sncf, dans le cas contraire nous vous invitons à privilégier d’autres modes de déplacement. Si vous le souhaitez, vous pouvez également obtenir l'échange ou le remboursement sans aucun frais sur OUI.sncfJe m'informeNos solutions alternativesCovoiturage Pratique, facile et direct. Trouvez votre covoiturage à proximité.Le bus Avec un large réseau, c'est l'une des meilleures alternatives au train.Location de voiture Besoin de flexibilité ? Louez votre voiture.Plus d'offres disponibles sur Oui.sncf dès maintenant.OUI.sncf est le distributeur de voyages en ligne de la SNCF sur la France et l'Europe :
# préparez vos voyages, réservez vos billets de train.
#
# Vous avez des choses à nous dire ?
# Nos conseillers sont là 24h/24, 7jours sur 7 par téléphone, t’chat, email ou sur les réseaux sociaux.Réservez, échangez ou annulez vos billets de train depuis votre mobile ou tabletteComparez les prix de nos billets de train et trouvez celui qui vous convientSi vous ne souhaitez plus recevoir d’emails de la part de OUI.sncf, vous pouvez vous désabonner en cliquant iciPour vous assurer de recevoir notre newsletter, nous vous recommandons d'ajouter l'adressebonsplans@newsletter.oui.sncf à vos contacts.En ouvrant cet email, vous acceptez le dépôt de nos cookies et ceux de nos partenaires a des fins de personnalisation d'annonces commerciales, de mesure ou d'analyse.Pour en savoir plus ou les configurer, suivez cette page.
# Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 € - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière :APS - R.C. : GAN - Récépissé CNIL n° 745549
#
#
#
# #####################################################
#
#
#
#
#
#
# IL NE VOUS RESTE PLUS QUE 48H POUR CONFIRMER VOTRE RÉSERVATION
#
#
#
# Pour visualiser ce message au format html, cliquez ici :
#
# ou copiez le lien dans votre navigateur Web
#
#
#
#
#
#
#  Vous avez posé une option sur vos billets de train sur Voyages-sncf.com à destination de PARIS GARE DE LYON.
#
#  Saviez-vous que votre réservation expire demain, le 08/12/2019 ? Pour garantir les tarifs et les critères de choix de votre voyage, confirmez votre réservation maintenant. Rien de plus facile : cliquez simplement sur le lien ci-dessous et réglez votre commande en ligne en toute sécurité avec Voyages-sncf.com.
#
#  ALLER Lundi 30/12/19 à 12h49
#
#  Référence du dossier : SMFPUU
#  Nom associé : BOETTO
#
#  Voir le détail de votre voyage
#
#
#  CONFIRMEZ VOTRE RéSERVATION
#
#
#
#
#
#  Si vous avez déjà confirmé votre commande, veuillez ne pas tenir compte de ce message.
#
#
#
#
#
# -----------------------------
# REJOIGNEZ-NOUS
# -----------------------------
#
# - Mobile
#
#
# - Facebook
#
#
# - Twitter
#
#
# - Google +
#
#
# - Sncf.com
#
#
#
#
#
# #####################################################
#
#
#
# Pour visualiser correctement cette lettre d'information, consultez la version en ligne.Le trafic SNCF sera fortement perturbé sur l’ensemble du réseau du 5 au 8 décembre 2019 en raison d’une grève nationale interprofessionnelle. Nous vous invitons à privilégier d’autres modes de déplacement. Si vous le souhaitez,vous pouvez également obtenir l'échange ou le remboursement sans aucun frais sur OUI.sncf.Je m'informeNos solutions alternativesCovoiturage Pratique, facile et direct. Trouvez votre covoiturage à proximité.Le bus Avec un large réseau, c'est l'une des meilleures alternatives au train.Location de voiture Besoin de flexibilité ? Louez votre voiture.Plus d'offres disponibles sur Oui.sncf dès maintenant.OUI.sncf est le distributeur de voyages en ligne de la SNCF sur la France et l'Europe :
# préparez vos voyages, réservez vos billets de train.
#
# Vous avez des choses à nous dire ?
# Nos conseillers sont là 24h/24, 7jours sur 7 par téléphone, t’chat, email ou sur les réseaux sociaux.Réservez, échangez ou annulez vos billets de train depuis votre mobile ou tabletteComparez les prix de nos billets de train et trouvez celui qui vous convientSi vous ne souhaitez plus recevoir d’emails de la part de OUI.sncf, vous pouvez vous désabonner en cliquant iciPour vous assurer de recevoir notre newsletter, nous vous recommandons d'ajouter l'adressebonsplans@newsletter.oui.sncf à vos contacts.En ouvrant cet email, vous acceptez le dépôt de nos cookies et ceux de nos partenaires a des fins de personnalisation d'annonces commerciales, de mesure ou d'analyse.Pour en savoir plus ou les configurer, suivez cette page.
# Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 € - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière :APS - R.C. : GAN - Récépissé CNIL n° 745549
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  Voyager à prix réduits, c'est Oui !
# Profitez de -30%(2) sur vos voyages et -60%(3) pour les enfants grâce à la carte Avantage à prix exceptionnel, et de plein d’autres surprises…
# Je fonce
#
#
#
#
#
# #####################################################
#
#
#
#  Partez au ski... sans les skis
# Cet hiver, on vous propose de changer vos habitudes :
# partez à la montagne et profitez de la neige sans dévaler les pistes !
# En savoir plus
#
#
#
#
#
#
# #####################################################
#
#
#
#  Voyager à prix réduits, c'est Oui !
# Profitez de -30%(2) sur vos voyages et -60%(3) pour les enfants grâce à la carte Avantage à prix exceptionnel, et de plein d’autres surprises…
# Je fonce
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
# IL NE VOUS RESTE PLUS QUE 48H POUR CONFIRMER VOTRE RÉSERVATION
#
#
#
# Pour visualiser ce message au format html, cliquez ici :
#
# ou copiez le lien dans votre navigateur Web
#
#
#
#
#
#
#  Vous avez posé une option sur vos billets de train sur Voyages-sncf.com à destination de PARIS GARE DE LYON.
#
#  Saviez-vous que votre réservation expire demain, le 24/11/2019 ? Pour garantir les tarifs et les critères de choix de votre voyage, confirmez votre réservation maintenant. Rien de plus facile : cliquez simplement sur le lien ci-dessous et réglez votre commande en ligne en toute sécurité avec Voyages-sncf.com.
#
#  ALLER Lundi 30/12/19 à 09h02
#
#  Référence du dossier : RADZET
#  Nom associé : BOETTO
#
#  Voir le détail de votre voyage
#
#
#  CONFIRMEZ VOTRE RéSERVATION
#
#
#
#
#
#  Si vous avez déjà confirmé votre commande, veuillez ne pas tenir compte de ce message.
#
#
#
#
#
# -----------------------------
# REJOIGNEZ-NOUS
# -----------------------------
#
# - Mobile
#
#
# - Facebook
#
#
# - Twitter
#
#
# - Google +
#
#
# - Sncf.com
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
# IL NE VOUS RESTE PLUS QUE 48H POUR CONFIRMER VOTRE RÉSERVATION
#
#
#
# Pour visualiser ce message au format html, cliquez ici :
#
# ou copiez le lien dans votre navigateur Web
#
#
#
#
#
#
#  Vous avez posé une option sur vos billets de train sur Voyages-sncf.com à destination de PARIS GARE DE LYON.
#
#  Saviez-vous que votre réservation expire demain, le 23/11/2019 ? Pour garantir les tarifs et les critères de choix de votre voyage, confirmez votre réservation maintenant. Rien de plus facile : cliquez simplement sur le lien ci-dessous et réglez votre commande en ligne en toute sécurité avec Voyages-sncf.com.
#
#  ALLER Dimanche 29/12/19 à 14h46
#
#  Référence du dossier : UNZTNK
#  Nom associé : BOETTO
#
#  Voir le détail de votre voyage
#
#
#  CONFIRMEZ VOTRE RéSERVATION
#
#
#
#
#
#  Si vous avez déjà confirmé votre commande, veuillez ne pas tenir compte de ce message.
#
#
#
#
#
# -----------------------------
# REJOIGNEZ-NOUS
# -----------------------------
#
# - Mobile
#
#
# - Facebook
#
#
# - Twitter
#
#
# - Google +
#
#
# - Sncf.com
#
#
#
#
#
# #####################################################
#
#
#
#  Pour visualiser correctement cette lettre d'information, consultez la version en ligne.
#
# Embarquez pour la Bretagne avec TGV INOUI à petits prix !
#
# Envie d'un bol d'air ?
# Nos idées week-ends à deux pas de Paris pour s’oxygéner...
# Plus de 100 000 billets à 39€ /aller pour la Bretagne et à -30% pour les encartés.
#
#
#
# Brest
# Au départ de Paris
# 3h13 en TGV
# Dès 39€(1)/AS
# Je réserve
#
#
#
# Saint-Malo
# Au départ de Paris
# 2h35 en TGV
# Dès 39€(1)/AS
# Je réserve
#
#
#
# Saint-Brieuc
# Au départ de Paris
# 2h06 en TGV
# Dès 39€(1)/AS
# Je réserve
#
#
#
# Vannes
# Au départ de Paris
# 2h18 en TGV
# Dès 45€(1)/AS
# Je réserve
#
#
#
# -------------------------------------------------------------------------------------
#
# 140 000 billets disponibles du 18 9, Prix TTC sur une sélection de destinations en France et en Europe et uniquement en 2nde classe, accessible de 120 jours jusqu'au départ du train et dans la limite des places disponibles à ce tarif sur les trains éligibles.
# Offre disponible sur TGV (hors OUIGO). Billets échangeables et remboursables sous conditions. Offre non cumulable avec toute autre promotion en cours, code avantage ou tarif réduit SNCF (hors Carte Avantage SNCF). Offre disponible uniquement en e-billet
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  La France à la vitesse de l'éclair !
# La gastronomie, le shopping, des moments inoubliables... Visitez la France à grande vitesse avec TGV INOUI jusqu'au 15 mars inclus
#
#
#
#
# #####################################################
#
#
#
#
#
#
# IL NE VOUS RESTE PLUS QUE 48H POUR CONFIRMER VOTRE RÉSERVATION
#
#
#
# Pour visualiser ce message au format html, cliquez ici :
#
# ou copiez le lien dans votre navigateur Web
#
#
#
#
#
#
#  Vous avez posé une option sur vos billets de train sur Voyages-sncf.com à destination de PARIS GARE DE LYON.
#
#  Saviez-vous que votre réservation expire demain, le 16/11/2019 ? Pour garantir les tarifs et les critères de choix de votre voyage, confirmez votre réservation maintenant. Rien de plus facile : cliquez simplement sur le lien ci-dessous et réglez votre commande en ligne en toute sécurité avec Voyages-sncf.com.
#
#  ALLER Dimanche 29/12/19 à 09h02
#
#  Référence du dossier : UABFDM
#  Nom associé : BOETTO
#
#  Voir le détail de votre voyage
#
#
#  CONFIRMEZ VOTRE RéSERVATION
#
#
#
#
#
#  Si vous avez déjà confirmé votre commande, veuillez ne pas tenir compte de ce message.
#
#
#
#
#
# -----------------------------
# REJOIGNEZ-NOUS
# -----------------------------
#
# - Mobile
#
#
# - Facebook
#
#
# - Twitter
#
#
# - Google +
#
#
# - Sncf.com
#
#
#
#
#
# #####################################################
#
#
#
#  50 000 billets à moins de 50euros(1)!
#
# Avec TGV INOUI, voyagez le samedi ou le dimanche et profitez du confort à petit prix.
# Partez vite découvrir le charme du Sud-Est à Aix-en-Provence, Nîmes, Marseille...
# ou faire un city break dans la capitale !
#
#
# Je réserve
# >>>>>>>>>>
#
#
# ------------------------------------------------------------------------------------------
#
# (1)Volumétrie de billets en date du 12/11/2019. Prix TTC par personne sur le trajet concerné, pour un aller simple uniquement en seconde classe, sur une sélection de destinations en France avec TGV INOUI ou TGV (hors OUIGO), dans la limite des places disponibles à ce tarif, certains jours et dans certains trains sans correspondance.
# Offre valable pour des voyages effectués samedi ou dimanche jusqu'au 29 mars inclus, hors période du 20 décembre 2019 au 5 janvier 2020 et du 8 février au 8 mars 2020 inclus. Billets échangeables et remboursables sous conditions. Offre non cumulable avec toute autre promotion en cours, code avantage ou tarif réduit SNCF (hors cartes Avantage SNCF).
# Offre disponible uniquement en e-billet.
#
#
#
#
# #####################################################
#
#
#
#  Pour visualiser correctement cette lettre d'information, consultez la version en ligne.
#
#
# Le bon plan pour une escapade d'automne
#
# Votre citybreak à Troyes
# Entre shopping, histoire, culture et chocolat, Troyes est la ville parfaite pour un city break automnal ! Prenez le train et laissez-vous tenter par son charme champenois.
# >>>>>
#
#
#
# Les incontournables
# Découvrez les pépites de
# la ville aux mille couleurs
# Je découvre
# >>>>>
#
#
# Les magasins d'usine
# Des marques à petit prix toute
# l'année, un rêve devenu réalité !
# J'y vais !
# >>>>>
#
#
#
# Troyes insolite
# Balades, musées, chocolats...
# Nos meilleures adresses !
# Je bouge
# >>>>>
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  À vous les dernières tendances culinaires !
#
# Suivez notre guide en 3 étapes pour devenir un pro des nouveautés food.
# Jusqu'où irez-vous ?
#
#
#
#
#
# #####################################################
#
#
#
#  -15€ sur vos voyages en Europe
# Profitez de 15€ de réduction dès 80€ d'achat avec le code ILOVEUROPE (1).
# Échappez-vous vers une sélection de villes en Europe pour un city-break hivernal !
#
#
#
#
#
#
# #####################################################
#
#
#
#  Bonjour,
#
#
# Votre train 6231 du 28/10/2019 départ à 16h07 ne pourra pas desservir la gare de PERPIGNAN en conséquence des travaux pour réparer les voies de chemin de fer endommagées par les précipitations du 23/10 entre Agde et Béziers.
#
# Nous vous proposons d'emprunter, sans échanger votre billet, le train 26651 au départ de PARIS MONTPARNASSE à 07h00 dont l’arrivée à PERPIGNAN est prévue à 14h10.
#
# Nous attirons votre attention sur le fait que le départ de votre train sera prévu en gare de PARIS MONTPARNASSE au lieu de PARIS GARE LYON.
#
# Si vous souhaitez reprogrammer votre voyage ou obtenir son remboursement, sans frais, nous vous invitons à vous rendre en ligne ( sur sncf.com sur le site de nos agences agréées ou dans l’un de nos autres points de vente.
#
# Nous nous excusons pour la gêne occasionnée.
#
#
# ----------------------------------------------
# Hello,
#
#
# Your train 6231 on 28/10/2019 will not be stopping at PERPIGNAN as a result of works to repair the railway tracks damaged by the rainfall between Agde and Beziers on the 23/10.
#
# Please take train 26651 from PARIS MONTPARNASSE at 07h00 and arriving PERPIGNAN at 14h10. There is no need to change your ticket.
#
# If you would like to reschedule your journey or refund your ticket, please contact your original selling point.
#
# Thank you for your understanding.
#
#
#
#
# #####################################################
#
#
#
#  Votre Carnet de Voyage TGV Inoui
#
# Pour visualiser correctement cette lettre d'information, copiez l'url ci-dessous dans un navigateur web :
#
#
#
#
#
# #####################################################
#
#
#
#  Bonjour,
#
# Votre train 6231 du 28/10/2019 départ à 16h07 ne pourra pas desservir la gare de PERPIGNAN en conséquence des travaux pour réparer les voies de chemin de fer endommagées par les précipitations du 23/10 entre Agde et Béziers.
#
# Nous vous invitons à reporter votre voyage.
#
# Si vous souhaitez reprogrammer votre voyage ou obtenir son remboursement, sans frais, nous vous invitons à vous rendre en ligne ( sur sncf.com sur le site de nos agences agréées ou dans l’un de nos autres points de vente.
#
# Nous nous excusons pour la gêne occasionnée.
#
#
# ----------------------------------------------------------------------------------------
#
# Hello,
#
# Your train 6231 on 28/10/2019 will not be stopping at PERPIGNAN as a result of works to repair the railway tracks damaged by the rainfall between Agde and Beziers on the 23/10.
#
# We invite you to postpone your trip.
#
# If you would like to reschedule your journey or refund your ticket, please contact your original selling point.
#
# Thank you for your understanding.
#
#
#
#
# #####################################################
#
#
#
#  OUI.SNCF
#
# MERCI ET BON VOYAGE
#
#
# Vos billets sont nominatifs et à usage strictement personnel.
#
#
# - - - - - - - - - - - - - - - - - - - - - - -
# VOTRE RÉSERVATION
# - - - - - - - - - - - - - - - - - - - - - - -
#
# - Aller LISIEUX - PARIS SAINT LAZARE 39,80 €
# - Référence : SXFEGK- Voyageurs : 2 voyageurs
# - Nom : Boetto
# - Mode de retrait : Mon e-billet
#
# Vos e-billets sont directement embarqués dans vos cartes de fidélité.
# Pour récupérer vos e-billets, avoir plus de détails sur votre réservation, la compléter, la modifier ou l’annuler, rendez-vous sur votre espace Mon Voyage
#
#
# ...
# Billets en vente du 15 avril au 22 mai 2018 inclus, pour des voyages effectués entre le 18 avril et le 1 septembre 2019 inclus, dans la limite des places disponibles à ce tarif.
# Possibilité de réserver jusqu'à 3 jours avant la date du voyage. Billets non échangeables et non remboursables. Offre non cumulable avec toute autre promotion en cours ou tarif réduit SNCF.
#
#
#
#
# #####################################################
#
#
#
#  Le TGV low cost au cœur de Paris
#
# Le TGV low cost vous attend en plein centre de la Capitale :
# vos billets dès 16€ depuis Gare de l'Est(1) et dès 19€ depuis Gare de Lyon et Montparnasse(1).
#
#
#
#
#
#
# #####################################################
#
#
#
#  Trouverez-vous notre lapin gourmand ?
# Miam Miam, Pâques approche… partez sur la trace de ce rongeur si mignon à Paris,
# Londres et Provins pour ramasser des tonnes de chocolats !
# Saurez-vous le dénicher dans nos articles ?
#
#
# ----------------------------------------------------------------------------
# Un saut à Paris
# Indice : notre grand gourmand se cache là où il y a le plus d’œufs de Pâques
#
#
# Un bond à Provins
# Indice : il aime résoudre des énigmes, surtout quand il y a du chocolat à la clé !
#
#
# Un Jump à Londres
# Indice : il file à l’anglaise pour tester des saveurs surprenantes
#
#
#
#
#
# #####################################################
#
#
#
#  N° de réclamation : R07401544
#
#
#
# Bonjour Christophe BOETTO,
#
# Suite à votre demande de compensation au titre de la G30 SNCF, nous avons le plaisir de vous adresser ci-dessous votre bon d’achat. Ce code valable 1 an, peut être utilisé pour vos futurs voyages sur des trajets TGV et INTERCITÉS en France métropolitaine. Il est utilisable aux guichets des gares et boutiques SNCF, par téléphone au 3635 (Service 0,40 €/min + prix appel), sur internet et l’ensemble des canaux progressivement.
#
#
#
#
# MONTANT : 4,90 €
#
# CODE CONSOMMATION : GPAAPHS4O
#
# DATE D’EXPIRATION : 28/01/2020 09:43
#
#
# Pour plus de détails sur les conditions d’utilisation de votre bon d’achat, cliquez sur ce lien
#
#
#
# Si vous rencontrez des difficultés à l’utilisation de votre bon d’achat, vous pouvez joindre le Support Bon d’Achat Digital :
#
# 0969 368 378 (appel non surtaxé)
#
#
#
#
# L’équipe G30 SNCF
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  Bonjour,
#
# Nous avons bien pris en compte votre demande qui sera traitée dans les meilleurs délais.
# Avec toute notre attention,
#
# Le Service G30 SNCF.
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  N° de réclamation (à rappeler lors de tout contact avec notre service client) : R06578182
#
#
#
# Bonjour Christophe BOETTO,
#
#
# Vous avez récemment consommé la totalité de votre Bon d’achat GPLMPQHQS d’une valeur de 19,80 €,
#
#
#
# Votre code n'est désormais plus utilisable.
#
#
# Cordialement.
#
# L’équipe G30 SNCF
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  N° de réclamation : R06578182
#
#
#
# Bonjour Christophe BOETTO,
#
# Suite à votre demande de compensation au titre de la G30 SNCF, nous avons le plaisir de vous adresser ci-dessous votre bon d’achat. Ce code valable 1 an, peut être utilisé pour vos futurs voyages sur des trajets TGV et INTERCITÉS en France métropolitaine. Il est utilisable aux guichets des gares et boutiques SNCF, par téléphone au 3635 (Service 0,40 €/min + prix appel), sur internet et l’ensemble des canaux progressivement.
#
#
#
#
# MONTANT : 19,80 €
#
# CODE CONSOMMATION : GPLMPQHQS
#
# DATE D’EXPIRATION : 05/11/2019 15:15
#
#
# Pour plus de détails sur les conditions d’utilisation de votre bon d’achat, cliquez sur ce lien
#
#
#
# Si vous rencontrez des difficultés à l’utilisation de votre bon d’achat, vous pouvez joindre le Support Bon d’Achat Digital :
#
# 0969 368 378 (appel non surtaxé)
#
#
#
#
# L’équipe G30 SNCF
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  Bonjour,
#
# Nous avons bien pris en compte votre demande qui sera traitée dans les meilleurs délais.
# Avec toute notre attention,
#
# Le Service G30 SNCF.
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#  Carnet de voyage Ouigo
#
#
#  Référence du dossier : REDM45
#
# MONTPELLIER
#
# MARNE LA VALLEE CHESSY
#
# Aller le 04/11/2018
#
# 16:15
#
# MONTPELLIER SUD DE FRANCE
#
# OUIGO
# 7848
#
#
# 19:36
#
# MARNE LA VALLEE TGV
#
# 2 passagers
#
# Si vous avez annulé votre commande, veuillez ne pas tenir compte de ce message.
#
#
#
#
#
# Astuce : lors de votre prochain voyage OUIGO, pensez à choisir l'option bagage supplémentaire à 5¿ lors de votre commande. En gare, il vous sera facturé 20¿ par bagage.
#
#
#
# Billet à imprimer
# Pensez à imprimer votre billet reçu par mail. Vous y retrouverez vos numéros de voiture et de place.
#
# E-billet
# Pratique et rapide ! Vous pouvez aussi télécharger votre E-Billet sur l'application OUI.sncf.
#
# Embarquement : Présentez-vous 30 min avant le départ du train en zone d'embarquement muni d'une pièce d'identité et de votre billet imprimé ou votre E-Billet.
#
# Accéder à ma réservation :
#
# Mon itinéraire
#
# Me rendre à la gare de départ en taxi, voiture, métro, bus...
#
# Renseigner mon adresse de départ
#
# Montpellier Sud De France
#
# Plans, parkings, services en gare
#
#
#
# La gare Montpellier-Sud de France se situe à 6km du centre ville. Cette gare est accessible en transport en commun.
#
#
#
# Marne La Vallee Tgv
#
# Plans, parkings, services en gare
#
#
#
# La gare Marne La Vallée Tgv se situe à environ 50&nbsp;mn de Châtelet-les Halles (centre de Paris) accessible en RER A.
#
#
#
# Rejoindre ma destination en taxi, voiture, métro, bus...
#
# Renseigner mon adresse d¿arrivée
#
#
# Votre taxi/chauffeur pour vous rendre à la gare ou en repartir
#
# Dès 10¿* avec iDCAB
#
#
#
# À faire : PARIS et ses environs...
# Cinq Bars secrets de la capitale
# Découvrez
#
# Art 42 - Le premier "mus&#233;e" street art de France &#224; Paris
#
# Découvrez
#
# Les mus&#233;es pour enfants &#224; Paris
#
# Découvrez
#
#
# SE LOGER
#
# Trouvez votre hôtel idéal
#
# Hôtel, Appart'hôtel, Auberge, ¿
# et bien d'autres !
#
# Réserver
#
#
#
#
#
#
# #####################################################
#
#
#
#   Pour visualiser correctement cette lettre d'information, consultez la version en ligne :
#
# POUR VOTRE VOYAGE A MONTPELLIER SAINT ROCH LE 31/10/2018 AVEC TGV
# -
#  Nous vous rappelons qu'avec l'appli OUI.sncf, vos billets sont directement dans votre mobile si vous avez choisi le e-billet.
# Accédez à votre train sans passer par la case compostage !
#
#
# Téléchargez l'application
#
#  LOUEZ VOTRE VOITURE EN GARE AVEC iDAVIS
#  -
# -15% GARANTIS(1)
# GRâCE à VOS
# CARTES SNCF
#
#
# VOS AVANTAGES
# - Grâce à votre carte de fidélité, 1 option offerte(2) (GPS, siège enfant, conducteur additionnel...).
# - Meilleur prix garanti(3) : Avis vous rembourse 2 fois la différence si vous trouvez moins cher ailleurs.
# - Une voiture à toute heure(4) : si votre agence est fermée à l'heure d'arrivée de votre train, un agent SNCF vous remet les clés.
#
# LOUEZ VOTRE VOITURE
#
#  NOS SERVICES POUR FACILITER VOTRE VOYAGE
#  -
#
# BAGAGES à DOMICILE
# Vos valises livrées à l'adresse de votre choix.
# Dès 20¿(7)
# Réservez
#  -
#
# VOTRE PARKING
# Votre place de parking réservée en gare de PARIS GARE DE LYON.
# Réservez
#
#  -
# VOTRE TAXI
# Votre chauffeur pour vous rendre à la gare ou en repartir.
# Dès 9,90¿ (8)
# Réservez
#
#
# RENDEZ-VOUS AU BAR TGV
# -
# Découvrez un large choix de repas et de petites douceurs sucrées et salées (voiture 4 ou 14).
#
# Découvrir la carte
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#  Paris s'offre à vous
# Plus calme, plus légère, plus ensoleillée... Paris, se découvre en été !
# Nous avons sélectionné pour vousles bonnes affaires pour profiter de Paris à petits prix.
# >>>Je dis OUI
#
#
#
#
#
# #####################################################
#
#
#
#  Renouvelez votre carte Jeune pour continuer à bénéficier de ses avantages !
#
#
#
#
# #####################################################
#
#
#
#  Partez à 2, payez pour 1 !
#
# Avec TGV, profitez des beaux jours d'été pour vous évader en France, du 20 juin au 2 septembre 2018.
# Offre à saisir jusqu'au 30 juin !
#
#
# ----------------------------------------------------------------------------------------------------
# iDAVIS : Location de voiture en gare
# Jusqu'au 30 juin, réservez 7 jours de location de voiture AVIS au prix de 5. Petite prix, grande escapade !
#
#
# Offre DUO au BAR TGV
# Jusqu'au 30 juin, commandez en ligne une boisson chaude et on vous offre la deuxième grâce au code BOISSONDUO !
#
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# #####################################################
#
#
#
#  Amsterdam, Bruxelles et Cologne en promo !
# Embarquez les copains, la petite sœur ou bien l’âme sœur et profitez de prix minis en Solo, en Duo (2 pers) ou en Colo (3-6 pers) avec Thalys pour voyager cet été aux Pays-Bas, en Belgique et en Allemagne. Faites vite !
# Vous avez jusqu'au 5 juin pour réserver vos billets.
#
#
#
#
#
# #####################################################
#
#
#
#  Un été So British avec Eurostar !
# Vos billets pour partir à Londres à prix doux cet été vous attendent. VITEEE ! Plus que 4 jours pour en profiter et voyager du 5 juin au 5 septembre inclus.
#
# ----------------------------------------------------------------------------
# Cet été, faites l'Europe buissonnière !
# Il reste de nombreux petits prix !
# Envie de bouger cet été ? C'est le moment de faire votre programme de vacances direction Amsterdam, Genève, Milan, Francfort...
#
# ----------------------------------------------------------------------------
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
# Pour visualiser correctement cette lettre d'information, consultez la version en ligne.Dernière minute :Billets disponibles pour vos voyages !Je réserveVoyagez bien informé(e) ! Sur le mois de mai, il reste des places disponibles à bord des TGV France et Europe, OUIGO et INTERCITÉS. De nombreuses destinations sont ouvertes à la vente. Tous les trains affichés circuleront. Pour réserver, rendez-vous sur nos site et application mobile OUI.sncf.Paris - LyonParis - StrasbourgParis - Bordeaux+ de destinationsPartagez vos plus belles photos de vacances sur instagram avec le hashtag #ONYVAOUl.sncf est le distributeur de voyages en ligne de la SNCF sur la France et l'Europe :
# préparez vos voyages, réservez vos billets de train, vol, hôtel.
#
# Vous avez des choses à nous dire ?
# Nos conseillers sont là 24h/24, 7jours sur 7 par téléphone, t'chat, email ou sur les réseaux sociaux.Réservez, échangez ou annulez vos billets de train depuis votre mobile ou tabletteComparez les prix de nos billets de train et trouvez celui qui vous convientSi vous ne souhaitez plus recevoir d'emails de la part de OUI.sncf, vous pouvez vous désabonner en cliquant iciPour vous assurer de recevoir notre newsletter, nous vous recommandons d'ajouter l'adressebonsplans@newsletter.oui.sncf à vos contacts.Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 € - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière :APS - R.C. : GAN - Récépissé CNIL n° 745549
#
#
#
# #####################################################
#
#
#
#  VOTRE VOYAGE VOUS ATTEND
#
# Vous avez récemment recherché des voyages en train que vous n'avez pas validés.
# Pour bénéficier des meilleurs prix, nous vous invitons à passer votre commande dès maintenant.
# Vous hésitez encore ? Posez une simple option et payez plus tard ! Un email de rappel vous sera envoyé 24 heures avant l'expiration de votre option
#
# Finalisez votre commande :
#
# Pour toute question ou remarque sur nos offres et services, cliquez ici exclusivement.
# En répondant directement à cette lettre d¿information, votre message ne pourrait être traité.
#
# Gérer votre abonnement :
# Vous désabonner :
#
# Voyages-sncf.com - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 ¿ - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière : APS - R.C. : GAN - Récépissé CNIL n° 745549
# L'Agence Voyages-sncf.com - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 439 202 078 - S.A.S. au capital de 3.000.000 ¿ - Licence d'agence de voyages n° LI 092 02 0021 - Garantie financière : APS - R.C. : GAN - Récépissé CNIL n° 776624
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
# Bonjour,
# Vous partez avec TGV à PERPIGNAN le Thu Dec 28 2017 08:01:00 GMT+0100 (CET).
#
# Pour voyager en toute sérénité, retrouvez les infos essentielles de votre réservation
#  et découvrez tous les services facilitant votre voyage:
#
#
# Pour vous désabonner:
#
#
#
# Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 euros - Licence d'agence de voyages n° LI 092 01 0002
# Garantie financière : APS - R.C. : GAN - Récépissé CNIL n° 745549
# L'Agence Oui.sncf - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 439 202 078 - S.A.S. au capital de 3.000.000 euros - Licence d'agence de voyages n° LI 092 02 0021
# Garantie financière : APS - R.C. : GAN - Récépissé CNIL n° 776624
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
# WEEK-ENDS ROMANTIQUES A PORTE DE TRAIN
# www.voyages-sncf.com/destinations/week-ends-romantiques
#
# C'est l'été avec TGV
# www.voyages-sncf.com/promotion-train/multi/odv-ete
#
# VOYAGEZ AU MEILLEUR PRIX
# calendrier.voyages-sncf.com/
#
# Spécial Saint-Valentin : à l'occasion des 30 ans du partenariat SNCF-AVIS, l'option GPS vous est offerte(6) pour votre escapade en amoureux avec iDAVIS.
# www.voyages-sncf.com/train/train-avis
#
#
# Pour toute question ou remarque sur nos offres et services, cliquez ici exclusivement :
# En répondant directement à cette lettre d'information, votre message ne pourrait être traité.
#
# - Gérer votre abonnement :
#
# - Vous désabonner :
#
#
#
#
# #####################################################
#
#
#
#  UNE NOUVELLE PAGE D'ACCUEIL,
# POUR VOUS ET AVEC VOUS
# ---------------------------------
#
# Pour que chacune de vos visites sur notre site soit une première étape de votre voyage, nous avons fait évoluer notre page d'accueil selon vos envies et vos suggestions.
#
#
#
# VOTRE PAGE D'ACCUEIL FAIT PEAU NEUVE
#
#
#
# DÉCOUVREZ VOTRE NOUVELLE PAGE D'ACCUEIL EN VIDÉO
#
#
#
# ----------------
#
#
# Voyages-sncf.com - 2, place de la Défense, CNIT 1, BP 440, 92 053 Paris la Défense Cedex - RCS Nanterre B 431 810 621 - S.A.S au capital de 10.672.000 euros - Licence d'agence de voyages n° LI 092 01 0002 - Garantie financière : APS - R.C. : GAN - Récépissé CNIL n° 745549
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Pour toute question ou remarque sur nos offres et services, veuiller cliquer
# ici.
#
#
#
#
# Merci de ne pas répondre directement à cette lettre d'information, votre
# message ne serait pas traité.
#
#
#
#
#
#
#
# #####################################################
#
#
#
#
#
#
#
# #####################################################
