# %%
import pandas as pd

from utils import tag_mail

# %%
df = pd.read_json(r'data/gmail_azoulai_basic.txt', encoding = 'utf-8')

# %%
df['cat'] = df.headers.apply(tag_mail)

df.loc[df.cat=='amazon']
# Out:
#                                                 snippet                date  \
# 366   Bonjour azoulai, Votre colis contenant ELEGOO ... 2019-10-20 07:05:45
# 367   Bonjour azoulai, Votre colis contenant ELEGOO ... 2019-10-20 07:03:21
# 368   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-10-19 23:49:02
# 369   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-10-19 08:46:41
# 370   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-10-18 18:37:34
# 794   Votre abonnement de un an démarre maintenant A... 2019-05-26 13:49:54
# 824   Merci d&#39;avoir visité Amazon.fr ! À votre d... 2019-05-16 18:34:55
# 825   Aide sur le mot de passe Pour vérifier votre i... 2019-05-16 18:33:00
# 862   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-04-29 22:52:37
# 864   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:52:04
# 865   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:51:11
# 866   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:50:25
# 867   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:49:26
# 868   Amazon.fr Modification de commande Bonjour azo... 2019-04-29 17:49:26
# 869   Amazon.fr Vos commandes | Votre compte | Amazo... 2019-04-29 17:48:41
# 870   Votre essai gratuit de 30 jours commence dès m... 2019-04-29 17:46:36
# 872   Bonjour, Veuillez utiliser le code suivant pou... 2019-04-29 17:40:20
# 1207  Dear Paul, Thank you for the time taken on you... 2019-02-07 14:08:21
# 1214  Dear Paul, Thank you for completing the online... 2019-02-07 08:55:14
# 1226  Dear Paul, Thank you very much for your applic... 2019-02-05 13:59:14
# 1307  Welcome to amazon.jobs! Click here to verify y... 2019-01-18 18:45:37
#
#                                                 headers  \
# 366   [{'name': 'From', 'value': '"Amazon.fr" <shipm...
# 367   [{'name': 'From', 'value': '"Amazon.fr" <shipm...
# 368   [{'name': 'From', 'value': '"Amazon.fr" <confi...
# 369   [{'name': 'From', 'value': '"Amazon.fr" <confi...
# 370   [{'name': 'From', 'value': '"Amazon.fr" <confi...
# 794   [{'name': 'From', 'value': 'Amazon Prime <prim...
# 824   [{'name': 'From', 'value': 'Amazon <modificati...
# 825   [{'name': 'From', 'value': '"Amazon.fr" <accou...
# 862   [{'name': 'From', 'value': '"Amazon.fr" <confi...
# 864   [{'name': 'From', 'value': '"order-update@amaz...
# 865   [{'name': 'From', 'value': '"order-update@amaz...
# 866   [{'name': 'From', 'value': '"order-update@amaz...
# 867   [{'name': 'From', 'value': '"order-update@amaz...
# 868   [{'name': 'From', 'value': '"order-update@amaz...
# 869   [{'name': 'From', 'value': '"Amazon.fr" <confi...
# 870   [{'name': 'From', 'value': 'Amazon Prime <prim...
# 872   [{'name': 'From', 'value': '"Amazon.fr" <accou...
# 1207  [{'name': 'From', 'value': 'Silvia Polvara <am...
# 1214  [{'name': 'From', 'value': 'Barbara Faber <ama...
# 1226  [{'name': 'From', 'value': 'Barbara Faber <ama...
# 1307  [{'name': 'From', 'value': 'noreply@mail.amazo...
#
#                                                    body     cat
# 366    Amazon.fr \n---------------------------------...  amazon
# 367    Amazon.fr \n---------------------------------...  amazon
# 368    Confirmation d'envoi Amazon.fr \nCommande #40...  amazon
# 369    Confirmation d'envoi Amazon.fr \nCommande #40...  amazon
# 370    Confirmation de votre commande Amazon.fr \n \...  amazon
# 794    Bonjour azoulai, \nA votre demande, nous vous...  amazon
# 824     Merci d'avoir visité Amazon.fr ! \n \n À vot...  amazon
# 825                                                      amazon
# 862    Confirmation d'envoi Amazon.fr \nCommande #40...  amazon
# 864    Mise à jour de votre commande Amazon.fr \nCom...  amazon
# 865    Mise à jour de votre commande Amazon.fr \nCom...  amazon
# 866    Mise à jour de votre commande Amazon.fr \nCom...  amazon
# 867    Mise à jour de votre commande Amazon.fr \nCom...  amazon
# 868    Mise à jour de votre commande Amazon.fr \nCom...  amazon
# 869    Confirmation de votre commande Amazon.fr \n \...  amazon
# 870    Bonjour azoulai, \n \nTestez gratuitement pen...  amazon
# 872                                                      amazon
# 1207   Dear Paul, \n  \nThank you for the time taken...  amazon
# 1214   Dear Paul, \n  \nThank you for completing the...  amazon
# 1226   Dear Paul, \n  \nThank you very much for your...  amazon
# 1307                                                     amazon

# %%
df = df.loc[df.cat=='amazon']
for el in df.body:
    print(el)
    print('\n\n')
    print('#######################################################')
    print('\n\n')
# Out:
#  Amazon.fr
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Bonjour azoulai,
#
# Votre colis contenant ELEGOO Kit DE 37-en-1... vous sera livré aujourd'hui.
#
#
# Si vous le souhaitez, vous pouvez ajouter des instructions de livraison. Pour ce faire, accédez à la page Suivre votre colis et reportez-vous à l’encadré « Livraison par Amazon » :
#
#
#
# Suivre votre colis:
#
#
# Commande n° 406-8066368-1154711
#
#  ELEGOO Kit DE 37-en-1 Module Capteur V2.0 avec CD Tutorial Complet et Accessible pour Raspberry Pi Débutants et Professionnels DIY
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Veuillez noter que ce message vous a été envoyé depuis une adresse ne pouvant recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Amazon.fr
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Bonjour azoulai,
#
# Votre colis contenant ELEGOO Kit Électronique Mis... vous sera livré aujourd'hui.
#
#
# Si vous le souhaitez, vous pouvez ajouter des instructions de livraison. Pour ce faire, accédez à la page Suivre votre colis et reportez-vous à l’encadré « Livraison par Amazon » :
#
#
#
# Suivre votre colis:
#
#
# Commande n° 406-8066368-1154711
#
#  ELEGOO Kit Électronique Mis à Jour avec Module d'alimentation, Câbles Jumpers, Potentiomètre de précision, Plaque de Test 830 Points pour
#
# --------------------------------------------------------------------------------------------------------------------------------------------
#
# Veuillez noter que ce message vous a été envoyé depuis une adresse ne pouvant recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Confirmation d'envoi Amazon.fr
# Commande #406-8066368-1154711
#
#
# --------------------------------------------------------------------
# Bonjour,
#
# Ceci est le dernier colis de votre commande, les autres articles ayant été expédiés précédemment.
#
# Livraison :
#  Dimanche 20 octobre 2019
#
#
#
# Suivez votre colis en cliquant sur le lien suivant :
#
#
# Votre commande a été expédiée à l'adresse suivante :
#
#  Paul Azoulai
#  7 Villa Emile Meyer
#  Paris,
#  75016
#  France
#
#
# Votre colis est expédié par Amazon Logistics et votre numéro de suivi est CC0011815509.
#
# Selon votre option de livraison il est possible que les informations de suivi ne soient pas encore consultables au moment où vous recevez cet e-mail. Veuillez consulter notre page d'aide pour plus d'informations sur le transporteur et obtenir l'adresse de son site de suivi en ligne :
#
#
# ====================================================================
#
# Votre Expédition
# (Vendu par ELEGOO Official - FR) :
#  ELEGOO Kit DE 37-en-1 Module Capteur V2.0 avec CD Tutorial Complet et Accessible pour Raspberry Pi Débutants et Professionnels DIY Compatible avec Ar
#  EUR 29,99
#
# --------------------------------------------------------------------
#  Sous-total des articles : EUR 24,99
#  Frais d'envoi : EUR 0,00
#
#  Total HT: EUR 24,99
#  TVA : EUR 5,00
#
#  Montant total pour cet envoi : EUR 29,99
#  Payé par Mastercard: EUR 29,99
#
# ====================================================================
#
# Commande #406-8066368-1154711
# Validée le 18 octobre 2019
#
# Articles déjà expédiés
#
# Date de livraison estimée: Dimanche 20 octobre 2019
#
#  ELEGOO Kit Électronique Mis à Jour avec Module d'alimentation, Câbles Jumpers, Potentiomètre de précision, Plaque de Test 830 Points pour Mega 25
#
# Pour nous retourner un article, notre Centre de retours en ligne est à votre disposition :
#
#
# En savoir plus sur le recyclage gratuit de votre appareil électrique ou électronique :
#
#
# Découvrez comment recycler votre emballage avec Amazon Second Chance(
# Si vous avez besoin d'aide supplémentaire, nous vous invitons à nous contacter :
#
#
# A bientôt sur Amazon.fr.
# Amazon.fr
#
# --------------------------------------------------------------------
#
# Vous pouvez vous rétracter de cette commande dans un délai de 14 jours à compter de la date à laquelle vous aurez reçu le(s) produit(s) (sous réserve de certaines exceptions, pour plus d'informations, veuillez vous rendre sur cette page :
#
# Nous vous rembourserons le prix du/des produit(s) et les frais de livraison standard (c’est à dire correspondant à la livraison la moins onéreuse que nous proposons). Vous prendrez à votre charge les frais de retour du/des produit(s), sauf si vous retournez des vêtements, chaussures ou accessoires (vous pouvez consulter nos politiques de retours en cliquant sur le lien suivant :
#
# Vous pourrez être amené à supporter des frais de retour supplémentaires si le(s) produit(s) ne peu(ven)t être retourné(s) normalement par la poste.
# Vous pouvez exercer votre droit de rétractation directement via notre centre de retours en ligne en cliquant sur le lien suivant : ou en nous contactant ; vous pouvez également nous envoyer un formulaire de retractation par courrier afin que nous fassions le nécessaire, vous trouverez ce formulaire en cliquant sur le lien suivant :
#
# Veuillez également consulter notre politique de retours (nous vous rembourserons le prix payé pour le(s) produit(s)). Pour en savoir plus sur notre politique de retours de 30 jours, cliquez sur lien suivant pour plus d'informations :
#
# Pour en savoir plus sur vos droits en application des garanties légales de conformité et des vices cachés, cliquez sur le lien suivant :
#
# Pour toute réclamation ou question complémentaire, veuillez contacter notre Service Client directement à l'aide de ce lien : www.amazon.fr/contactez-nous.
#
# Amazon EU, Société à responsabilité limitée, 38 avenue John F. Kennedy, L-1855 Luxembourg. Capital Social: EUR 125.000. Numéro de RCS au Luxembourg: B 101818. Numéro de licence: 134248. Numéro de TVA communautaire: LU 20260743
#
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Confirmation d'envoi Amazon.fr
# Commande #406-4673949-5961163
#
#
# --------------------------------------------------------------------
# Bonjour,
#
# Nous vous informons que votre commande a été expédiée par le vendeur Dolity EU. Votre colis est en cours d'acheminement et cette commande ne peut donc plus être modifiée.
#
# Livraison :
#  Lundi 18 novembre 2019
#
#
#
# Suivez votre colis en cliquant sur le lien suivant :
#
#
# Votre commande a été expédiée à l'adresse suivante :
#
#  Paul Azoulai
#  7 Villa Emile Meyer
#  Paris,
#  75016
#  France
#
#
# Votre colis est expédié par Standard et les informations de suivi ne sont pas disponibles.
#
# Pour comprendre pourquoi le suivi de votre colis n'est pas disponible, veuillez consulter notre page d'aide :
#
#
#
# ====================================================================
#
# Votre Expédition
# (Vendu par Dolity EU) :
#  Gazechimp Module de Relais Shield 4 Canaux pour Raspberry PI A+/B+/pi 2Model B/PI 3 Model B
#  EUR 8,98
#  Etat : Neuf
#
# --------------------------------------------------------------------
#  Sous-total des articles : EUR 8,98
#  Frais d'envoi : EUR 0,00
#
#
#  Montant total pour cet envoi : EUR 8,98
#  Payé par Mastercard: EUR 8,98
#
# ====================================================================
# Pour nous retourner un article, notre Centre de retours en ligne est à votre disposition :
#
#
# En savoir plus sur le recyclage gratuit de votre appareil électrique ou électronique :
#
#
# Si vous avez besoin d'aide supplémentaire, nous vous invitons à contacter Dolity EU:
#
#
# A bientôt sur Amazon.fr.
# Amazon.fr
#
# --------------------------------------------------------------------
#
# Visitez notre Centre de retours en ligne si vous souhaitez retourner un article en cliquant sur le lien suivant : Si vous ne voulez pas utiliser notre Centre de retours en ligne et souhaitez exercer votre droit de rétractation, vous pouvez utiliser ce formulaire de rétraction et nous le transmettre par courrier à l'adresse indiquée :
#
# Pour toute réclamation ou question complémentaire, veuillez contacter notre Service Client directement à l'aide de ce lien : www.amazon.fr/contactez-nous.
#
# Amazon EU, Société à responsabilité limitée, 38 avenue John F. Kennedy, L-1855 Luxembourg. Capital Social: EUR 125.000. Numéro de RCS au Luxembourg: B 101818. Numéro de licence: 134248. Numéro de TVA communautaire: LU 20260743
#
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Confirmation de votre commande Amazon.fr
#
# Commande n° 406-4673949-5961163
# Commande n° 406-8066368-1154711
#
# _____________________________________________________________________________________
#
# Bonjour,
#
# Nous vous remercions de votre commande. Nous vous tiendrons informés par e-mail lorsque les articles de votre commande auront été expédiés.
#
# Votre date de livraison estimée est indiquée ci-dessous.
# Vous pouvez suivre l'état de votre commande ou modifier celle-ci en vous rendant dans la section Vos commandes sur Amazon.fr :
#
#
# Votre achat a été divisé en 2 commandes.
#
# =====================================================================================
#
# Détails de la commande
#
#
# Commande n° 406-4673949-5961163
# Effectuée le 18 octobre 2019
#  Livraison :
#  Jeudi 7 novembre -
#  Lundi 18 novembre
#
#  Votre mode de livraison :
#  Livraison Standard
#
#  Votre commande sera expédiée à :
#  Paul Azoulai
#  7 Villa Emile Meyer
#  Paris, 75016
#  France
#
# Vos articles :
#  Gazechimp Module de Relais Shield 4 Canaux pour Raspberry PI A+/B+/pi 2Model B/PI 3 Model B
#  EUR 8,98
#  Etat : Neuf
#  Vendu par Dolity EU
#
# _______________________________________________________________________________________
#
#  Sous-total des articles : EUR 8,98
#  Frais d'envoi : EUR 0,00
#
#
#
#  Montant total de la commande : EUR 8,98
#  Moyen de paiement sélectionné : Mastercard
#
# =======================================================================================
#
#
# Commande n° 406-8066368-1154711
# Effectuée le 18 octobre 2019
#  Livraison :
#  Dimanche 20 octobre
#
#  Votre mode de livraison :
#  Livraison en 1 jour ouvré
#
#  Vos préférences d'expédition :
#  Envoyer chaque article dès qu'il est disponible.
#
#  Votre commande sera expédiée à :
#  Paul Azoulai
#  7 Villa Emile Meyer
#  Paris, 75016
#  France
#
# Vos articles :
#  ELEGOO Kit Électronique Mis à Jour avec Module d'alimentation, Câbles Jumpers, Potentiomètre de précision, Plaque de Test 830 Points pour Mega 2560 Nano Raspberry Pi et STM32
#  EUR 15,86
#  Etat : Neuf
#  Vendu par ELEGOO Official - FR
#  Expédié par Amazon
#
#  ELEGOO Kit DE 37-en-1 Module Capteur V2.0 avec CD Tutorial Complet et Accessible pour Raspberry Pi Débutants et Professionnels DIY Compatible avec Arduino IDE
#  EUR 29,99
#  Etat : Neuf
#  Vendu par ELEGOO Official - FR
#  Expédié par Amazon
#
# _______________________________________________________________________________________
#
#  Sous-total des articles : EUR 38,21
#  Frais d'envoi : EUR 0,00
#
#
#
#  Total HT : EUR 38,21
#  TVA : EUR 7,64
#
#  Montant total de la commande : EUR 45,85
#  Moyen de paiement sélectionné : Mastercard
#
# =======================================================================================
# Vous souhaitez modifier votre commande ? Consultez notre page d'Aide et nos vidéos pour plus d'informations :
#
#
# Nous espérons vous revoir bientôt.
#
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _____________________________________________________________________________________
#
# Les articles faisant partie du service Expédié par Amazon sont proposés par des vendeurs tiers et stockés par ces derniers dans l'un de nos dépôts de marchandises. Amazon prend en charge la préparation de votre commande et son expédition. Par ailleurs, les articles proposés par Offres Reconditionnées font également partie du service Expédié par Amazon. Offres Reconditionnées est une marque déposée par Amazon EU S.à r.l. et appartient au groupe Amazon.com. En savoir plus sur le service Expédié par Amazon :
#
#
# Sauf mention contraire, les articles vendus par Amazon EU S.à r.l. sont soumis à la Taxe sur la Valeur Ajoutée applicable dans le pays de destination, selon les lois européennes en vigueur sur la vente à distance. En savoir plus sur la TVA et les vendeurs :
#
#
# Si les articles ont été achetés auprès d'un vendeur Amazon Marketplace, celui-ci pourra vous demander des informations complémentaires, telles que votre numéro de TVA ou votre code fiscal, afin d'émettre une facture valide.
#
# Cet e-mail est un accusé de réception de votre commande et vaut confirmation du contrat d'achat. Un e-mail confirmant l'expédition de vos articles vous sera envoyé prochainement.
#
#
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Bonjour azoulai,
# A votre demande, nous vous rappelons que votre essai gratuit de 30 jours se termine bientôt.
#  <p>Le 29 mai 2019 votre essai gratuit deviendra une adhésion annuelle et 49,00€/an vous seront débités pour Amazon Prime. Vous continuerez de profiter des avantages de livraison Amazon Prime ainsi que Prime Video et bien d’autres avantages Amazon Prime</p>
#
# Si vous ne souhaitez pas continuer avec une adhésion payante, merci de vous rendre sur la page « Amazon Prime : gérer mes paramètres » et cliquez sur « Terminer l’adhésion ». Votre carte ne sera pas débitée et vous perdrez vos avantages Amazon Prime en mettant fin à votre adhésion.
# Merci d'être membre d'Amazon Prime.
# =====================================================================
# © 2014 Amazon EU société à responsabilité limitée, 5 rue Plaetis, L-2338 Luxembourg. Capital social : EUR 37.500. RCS Luxembourg numéro : B 101818. Numéro de licence : 134248. Numéro de TVA intracommunautaire : LU 20260743.
#
#
#
# Ce message a été envoyé à : pazoulai@gmail.com
#
#
#
# #######################################################
#
#
#
#   Merci d'avoir visité Amazon.fr !
#
#  À votre demande, votre mot de passe a bien été modifié.
#
#  Consultez la rubrique Votre compte sur Amazon.fr pour afficher vos commandes, modifier toute commande qui n'est pas encore en cours d'expédition, modifier vos inscriptions, et plus encore.
#
#  Si vous avez besoin de nous contacter, quelle que soit la raison, sachez que nous ne pouvons dévoiler des informations sur les commandes qu'à la personne correspondant au nom et à l'adresse électronique associés à votre compte.
#
#  Merci d'avoir acheté des articles sur notre site.
#  </p>
#
#
#
# #######################################################
#
#
#
#
#
#
#
# #######################################################
#
#
#
#  Confirmation d'envoi Amazon.fr
# Commande #408-7806068-3676305
#
#
# --------------------------------------------------------------------
# Bonjour,
#
# Nous vous informons que votre commande a été expédiée. Votre colis est en cours d'acheminement et cette commande ne peut donc plus être modifiée.
#
# Livraison :
#  Mardi 30 avril 2019
#
#
#
# Suivez votre colis en cliquant sur le lien suivant :
#
#
# Votre commande a été expédiée à l'adresse suivante :
#
#  Paul Azoulai
#  Lohmühlenstraße 65
#  Berlin,
#  Berlin
#  12435
#  Allemagne
#
#
# Votre colis est expédié par Amazon Logistics et votre numéro de suivi est AH0302072263.
#
# Selon votre option de livraison il est possible que les informations de suivi ne soient pas encore consultables au moment où vous recevez cet e-mail. Veuillez consulter notre page d'aide pour plus d'informations sur le transporteur et obtenir l'adresse de son site de suivi en ligne :
#
#
# ====================================================================
#
# Votre Expédition
#
# (Vendu par Amazon EU S.a.r.L.) :
#  Fluent Python
#  EUR 36,70
#
#
# (Vendu par Amazon EU S.a.r.L.) :
#  Clean Code: A Handbook of Agile Software Craftsmanship
#  EUR 29,08
#
# --------------------------------------------------------------------
#  Sous-total des articles : EUR 61,48
#  Frais d'envoi : EUR 11,00
#
#  Total HT: EUR 72,48
#  TVA : EUR 5,07
#
#  Montant total pour cet envoi : EUR 77,55
#  Payé par Mastercard: EUR 77,55
#
# ====================================================================
#
# Vous souhaitez voir ou imprimer votre facture ? Rendez-vous sur Détails des commandes :
#
#
# En savoir plus :
#
#
# Pour nous retourner un article, notre Centre de retours en ligne est à votre disposition :
#
#
# En savoir plus sur le recyclage gratuit de votre appareil électrique ou électronique :
#
#
# Si vous avez besoin d'aide supplémentaire, nous vous invitons à nous contacter :
#
#
# A bientôt sur Amazon.fr.
# Amazon.fr
#
# --------------------------------------------------------------------
#
# Vous pouvez vous rétracter de cette commande dans un délai de 14 jours à compter de la date à laquelle vous aurez reçu le(s) produit(s) (sous réserve de certaines exceptions, pour plus d'informations, veuillez vous rendre sur cette page :
#
# Nous vous rembourserons le prix du/des produit(s) et les frais de livraison standard (c’est à dire correspondant à la livraison la moins onéreuse que nous proposons). Vous prendrez à votre charge les frais de retour du/des produit(s), sauf si vous retournez des vêtements, chaussures ou accessoires (vous pouvez consulter nos politiques de retours en cliquant sur le lien suivant :
#
# Vous pourrez être amené à supporter des frais de retour supplémentaires si le(s) produit(s) ne peu(ven)t être retourné(s) normalement par la poste.
# Vous pouvez exercer votre droit de rétractation directement via notre centre de retours en ligne en cliquant sur le lien suivant : ou en nous contactant ; vous pouvez également nous envoyer un formulaire de retractation par courrier afin que nous fassions le nécessaire, vous trouverez ce formulaire en cliquant sur le lien suivant :
#
# Veuillez également consulter notre politique de retours (nous vous rembourserons le prix payé pour le(s) produit(s)). Pour en savoir plus sur notre politique de retours de 30 jours, cliquez sur lien suivant pour plus d'informations :
#
# Pour en savoir plus sur vos droits en application des garanties légales de conformité et des vices cachés, cliquez sur le lien suivant :
#
# Pour toute réclamation ou question complémentaire, veuillez contacter notre Service Client directement à l'aide de ce lien : www.amazon.fr/contactez-nous.
#
# Amazon EU, Société à responsabilité limitée, 38 avenue John F. Kennedy, L-1855 Luxembourg. Capital Social: EUR 125.000. Numéro de RCS au Luxembourg: B 101818. Numéro de licence: 134248. Numéro de TVA communautaire: LU 20260743
#
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Mise à jour de votre commande Amazon.fr
# Commande n° 408-7806068-3676305
# www.amazon.fr/ref=TE_tex_h
# _______________________________________________________________________________________
#
# Bonjour azoulai,
#
# Vous avez mis à jour le mode de livraison de votre commande. Nous vous enverrons un e-mail de confirmation lorsque vos articles seront expédiés. Si vous souhaitez consulter l'état de votre commande, rendez-vous dans Vos commandes sur Amazon.fr :
#
#
#  Mode de livraison mis à jour :
#  Livraison en 1 jour ouvré
#
# =======================================================================================
#
# Détails de la commande
# Commande n° 408-7806068-3676305
# Effectuée le 29 avril 2019
#
# Livraison estimée : Mardi 30 avril 2019
#
#
#  Fluent Python
#  par Ramalho, Luciano
#  Vendu par : Amazon EU S.a.r.L.
#
#
#  Clean Code: A Handbook of Agile Software Craftsmanship
#  par Martin, Robert
#  Vendu par : Amazon EU S.a.r.L.
#
# _______________________________________________________________________________________
#
#  Montant total de la commande : EUR 77,55
#
# =======================================================================================
#
# Si vous avez besoin d'assistance supplémentaire, veuillez visiter nos pages d'aide :
#
#
# Nous espérons vous revoir bientôt.
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _______________________________________________________________________________________
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Mise à jour de votre commande Amazon.fr
# Commande n° 408-7806068-3676305
# www.amazon.fr/ref=TE_tex_h
# _______________________________________________________________________________________
#
# Bonjour azoulai,
#
# Vous avez mis à jour l'adresse de livraison de votre commande. Nous vous enverrons un e-mail de confirmation lorsque vos articles seront expédiés. Si vous souhaitez consulter l'état de votre commande, rendez-vous dans Vos commandes sur Amazon.fr :
#
#
#  Votre commande sera à présent expédiée à :
#  Paul Azoulai
#  Lohmühlenstraße 65
#  Berlin,
#  Berlin
#  12435
#  Allemagne
#
# =======================================================================================
#
# Détails de la commande
# Commande n° 408-7806068-3676305
# Effectuée le 29 avril 2019
#
# Livraison estimée : Vendredi 3 mai 2019
#
#
#  Fluent Python
#  par Ramalho, Luciano
#  Vendu par : Amazon EU S.a.r.L.
#
#
#  Clean Code: A Handbook of Agile Software Craftsmanship
#  par Martin, Robert
#  Vendu par : Amazon EU S.a.r.L.
#
# _______________________________________________________________________________________
#
#  Montant total de la commande : EUR 71,90
#
# =======================================================================================
#
# Si vous avez besoin d'assistance supplémentaire, veuillez visiter nos pages d'aide :
#
#
# Nous espérons vous revoir bientôt.
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _______________________________________________________________________________________
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Mise à jour de votre commande Amazon.fr
# Commande n° 408-7806068-3676305
# www.amazon.fr/ref=TE_tex_h
# _______________________________________________________________________________________
#
# Bonjour azoulai,
#
# Vous avez mis à jour le mode de livraison de votre commande. Nous vous enverrons un e-mail de confirmation lorsque vos articles seront expédiés. Si vous souhaitez consulter l'état de votre commande, rendez-vous dans Vos commandes sur Amazon.fr :
#
#
#  Mode de livraison mis à jour :
#  Livraison Standard
#
# =======================================================================================
#
# Détails de la commande
# Commande n° 408-7806068-3676305
# Effectuée le 29 avril 2019
#
# Livraison estimée : Vendredi 3 mai 2019
#
#
#  Fluent Python
#  par Ramalho, Luciano
#  Vendu par : Amazon EU S.a.r.L.
#
#
#  Clean Code: A Handbook of Agile Software Craftsmanship
#  par Martin, Robert
#  Vendu par : Amazon EU S.a.r.L.
#
# _______________________________________________________________________________________
#
#  Montant total de la commande : EUR 71,90
#
# =======================================================================================
#
# Si vous avez besoin d'assistance supplémentaire, veuillez visiter nos pages d'aide :
#
#
# Nous espérons vous revoir bientôt.
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _______________________________________________________________________________________
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Mise à jour de votre commande Amazon.fr
# Commande n° 408-7806068-3676305
# www.amazon.fr/ref=TE_tex_h
# _______________________________________________________________________________________
#
# Bonjour azoulai,
#
# Vous avez mis à jour le mode de livraison de votre commande. Nous vous enverrons un e-mail de confirmation lorsque vos articles seront expédiés. Si vous souhaitez consulter l'état de votre commande, rendez-vous dans Vos commandes sur Amazon.fr :
#
#
#  Mode de livraison mis à jour :
#  Livraison en 1 jour ouvré
#
# =======================================================================================
#
# Détails de la commande
# Commande n° 408-7806068-3676305
# Effectuée le 29 avril 2019
#
# Livraison estimée : Mardi 30 avril 2019
#
#
#  Fluent Python
#  par Ramalho, Luciano
#  Vendu par : Amazon EU S.a.r.L.
#
#
#  Clean Code: A Handbook of Agile Software Craftsmanship
#  par Martin, Robert
#  Vendu par : Amazon EU S.a.r.L.
#
# _______________________________________________________________________________________
#
#  Montant total de la commande : EUR 77,55
#
# =======================================================================================
#
# Si vous avez besoin d'assistance supplémentaire, veuillez visiter nos pages d'aide :
#
#
# Nous espérons vous revoir bientôt.
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _______________________________________________________________________________________
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Mise à jour de votre commande Amazon.fr
# Commande n° 408-7806068-3676305
# www.amazon.fr/ref=TE_tex_h
# _______________________________________________________________________________________
#
# Bonjour azoulai,
#
# Vous avez mis à jour l'adresse de livraison de votre commande. Nous vous enverrons un e-mail de confirmation lorsque vos articles seront expédiés. Si vous souhaitez consulter l'état de votre commande, rendez-vous dans Vos commandes sur Amazon.fr :
#
#
#  Votre commande sera à présent expédiée à :
#  Paul Azoulai
#  Lohmühlenstraße 65
#  Berlin,
#  Berlin
#  12435
#  Allemagne
#
# =======================================================================================
#
# Détails de la commande
# Commande n° 408-7806068-3676305
# Effectuée le 29 avril 2019
#
# Livraison estimée : Mardi 30 avril 2019
#
#
#  Fluent Python
#  par Ramalho, Luciano
#  Vendu par : Amazon EU S.a.r.L.
#
#
#  Clean Code: A Handbook of Agile Software Craftsmanship
#  par Martin, Robert
#  Vendu par : Amazon EU S.a.r.L.
#
# _______________________________________________________________________________________
#
#  Montant total de la commande : EUR 77,55
#
# =======================================================================================
#
# Si vous avez besoin d'assistance supplémentaire, veuillez visiter nos pages d'aide :
#
#
# Nous espérons vous revoir bientôt.
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _______________________________________________________________________________________
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Confirmation de votre commande Amazon.fr
#
# Commande n° 408-7806068-3676305
#
# _____________________________________________________________________________________
#
# Bonjour,
#
# Nous vous remercions de votre commande. Nous vous tiendrons informés par e-mail lorsque les articles de votre commande auront été expédiés.
#
# Votre date de livraison estimée est indiquée ci-dessous.
# Vous pouvez suivre l'état de votre commande ou modifier celle-ci en vous rendant dans la section Vos commandes sur Amazon.fr :
#
#
#
#  Livraison :
#  Mardi 30 avril
#
#  Votre mode de livraison :
#  Livraison en soirée
#
#  Votre commande sera expédiée à :
#  Paul Azoulai
#  7 Villa Emile Meyer
#  Paris, 75016
#  France
#
# =====================================================================================
#
# Détails de la commande
# Commande n° 408-7806068-3676305
# Effectuée le 29 avril 2019
#
# Vos articles :
#  Fluent Python de Ramalho, Luciano
#  EUR 36,19
#  Vendu par Amazon EU S.a.r.L.
#
#  Clean Code: A Handbook of Agile Software Craftsmanship de Martin, Robert
#  EUR 28,67
#  Vendu par Amazon EU S.a.r.L.
#
# _______________________________________________________________________________________
#
#  Sous-total des articles : EUR 61,48
#  Frais d'envoi : EUR 4,73
#  Promotion appliquée : -EUR 4,72
#
#
#
#  Total HT : EUR 61,49
#  TVA : EUR 3,38
#
#  Montant total de la commande : EUR 64,87
#  Moyen de paiement sélectionné : Mastercard
#
# =======================================================================================
# Vous souhaitez modifier votre commande ? Consultez notre page d'Aide et nos vidéos pour plus d'informations :
#
#
# Nous espérons vous revoir bientôt.
#
# Amazon.fr
# www.amazon.fr/ref=TE_tex_ty
# _____________________________________________________________________________________
#
# Sauf mention contraire, les articles vendus par Amazon EU S.à r.l. sont soumis à la Taxe sur la Valeur Ajoutée applicable dans le pays de destination, selon les lois européennes en vigueur sur la vente à distance. En savoir plus sur la TVA et les vendeurs :
#
#
# Cet e-mail est un accusé de réception de votre commande et vaut confirmation du contrat d'achat. Un e-mail confirmant l'expédition de vos articles vous sera envoyé prochainement.
#
#
# Veuillez noter que ce message vous a été envoyé d'une adresse qui ne peut recevoir d'e-mails. Merci de ne pas y répondre.
#
#
#
# #######################################################
#
#
#
#  Bonjour azoulai,
#
# Testez gratuitement pendant 30 jours vos avantages Amazon Prime :
#
#
#
# La livraison GRATUITE* et illimitée en 1 jour ouvré sur plus de 2 millions de références mais aussi de la livraison gratuite en 2 jours ouvrés sur 3 millions d’articles supplémentaires (Astuce : les articles éligibles sont signalés par un badge Prime)
#
#
# L'accès à des films et séries populaires ainsi qu'aux séries Prime Original en streaming immédiat sur PrimeVideo.com
#
#
# Prime Music: plus de 2 millions de titres à écouter sur tous vos appareils préférés, sans publicité et disponible en mode hors connexion. Disponible en France métropolitaine uniquement.
#
#
# Twitch Prime : des contenus de jeu additionnels gratuits tous les mois et une expérience améliorée sur twitch.tv.
#
#
#  Le stockage GRATUIT et illimité de vos photos sur Amazon Drive avec Prime Photos
#
#
# Prime Reading: accès à un catalogue de plusieurs centaines d’eBooks mis à jour régulièrement, depuis votre liseuse Kindle, votre smartphone ou votre tablette via l’application Kindle gratuite, ainsi que depuis votre ordinateur.
#
#
# Accès à une offre annuelle exclusive pour économiser sur votre abonnement Amazon Music Unlimited. Actuellement, l’abonnement Amazon Music Unlimited n’est disponible que pour les clients situés en France métropolitaine.
#
#
# Un accès prioritaire aux Ventes Flash éligibles Amazon.fr 30 minutes avant le démarrage officiel
#
#
#
# Lisez, partagez, achetez et soyez livré en un rien de temps grâce au programme Amazon Prime. Si vous êtes satisfait, ne faites rien : votre adhésion continuera automatiquement.
#
# Merci,
#
# L'équipe Amazon Prime
#
#
#
# Vous pouvez bénéficier de tous les avantages du programme Amazon Prime dès que vous êtes inscrit. *Pendant l'essai gratuit, la livraison en 1 jour ouvré vers la France est à 0,01€ pour les livres.
#
# A l'issue de l'essai gratuit de 30 jours, le programme sera automatiquement converti en inscription annuelle facturée EUR 49,00 par an. Si vous ne souhaitez pas convertir votre essai gratuit de 30 jours en inscriptions annuelle payante, rendez-vous dans les paramètres de votre compte ou utilisez ce formulaire de rétractation.
#
# Vous pouvez annuler votre inscription au programme Amazon Prime à tout moment directement dans Votre compte tant que ni vous ni aucun de vos invités n'avez effectué d'achat éligible ou bénéficié des avantages Amazon Prime. Nous vous rembourserons l'intégralité des frais annuels du programme Amazon Prime.
#
# Ce service a une durée annuelle et sera renouvelé automatiquement. Si vous ne voulez pas que votre inscription se renouvelle automatiquement, vous pouvez modifier ce paramètre directement dans Votre compte à tout moment et vous ne serez pas facturé pour l’année suivante. .
#
# Pour toute réclamation, veuillez cliquer ici et pour toute question complémentaire, veuillez prendre contact avec notre Service Client.
#
# Pour en savoir plus sur le programme Amazon Prime, veuillez consulter nos Conditions Générales d'Amazon Prime.
#
# Amazon.fr est le nom commercial Amazon EU société à responsabilité limitée, 38 avenue John F. Kennedy, L-1855 Luxembourg, Grand- Duché du Luxembourg. Capital social : EUR 37.500. RCS Luxembourg numéro : B 101818. Numéro de licence : 134248. Numéro de TVA intracommunautaire : LU 20260743.
# France.
#
#
#
#
# Ce message a été envoyé à : pazoulai@gmail.com
#
#
#
# #######################################################
#
#
#
#
#
#
#
# #######################################################
#
#
#
#  Dear Paul,
#
# Thank you for the time taken on your application for the position of Applied Science Intern &ndash; Robotics AI (m/f). We are sorry to inform you that, for this particular role, your application will not be considered further.
#
# Should there be suitable vacancies in the future, we may contact you. As outlined in our EU Candidate Privacy Notice, you can let us know if you do not want to be contacted for that purpose. Please refer to the "what are my rights under applicable data protection laws" section of the Notice for more information.
#
#
# We encourage you to visit our career website (www.amazon.jobs) as new positions become available.
#
# Thank you again for your time and interest in Amazon.
#
# Kind Regards,
# Amazon Recruitment Team
# (Please do not reply to this email - we are unable to review and respond to messages at this address)
#
#
#
#
# Discover Amazon's diverse and inclusive culture!
#
# Protecting your privacy and the security of your data is a longstanding top priority for Amazon. Please consult our Privacy Notice to know more about how we collect, use and transfer the personal data of our candidates. If you want to exercise your data subject rights please email EU-privacy-DSR@amazon.com
#
#
#
#
# **************************************************
# This message was sent to pazoulai@gmail.com. If you don't want to receive these emails from this company in the future, please go to:
#
# /n &#169; Amazon; P.O. Box 80683; Seattle, WA 98108-1226; USA/n
#
#
#
# #######################################################
#
#
#
#  Dear Paul,
#
# Thank you for completing the online assessment, as well as for the time and effort you have invested in the selection process.
#
# We have reviewed your profile and unfortunately following careful consideration of the information gathered through the recruitment process, we will not be proceeding with your application at this point.  Due to Amazon's privacy policy, we are not able to give specific feedback regarding your application.
#
# We would like to keep in touch with you to inform you about future job vacancies. As outlined in our EU Candidate Privacy Notice, you can let us know if you do not want to be contacted for that purpose. Please refer to the “What are my rights under applicable data protection laws?” section of the Notice for more information.
#
# Thank you again for your interest and we wish you all the best in your future career.
#
# Kind Regards,
# Student Programs Recruitment Team
# (Please do not reply to this email - we are unable to review and respond to messages at this address.)
#
# Amazon is an equal opportunities employer. We believe passionately that employing a diverse workforce is central to our success. We make recruiting decisions based on your experience and skills. We value your passion to discover, invent, simplify and build.
# Protecting your privacy and the security of your data is a longstanding top priority for Amazon. Please consult our Privacy Notice to know more about how we collect, use and transfer the personal data of our candidates.
#
#
#
#
#
#
# **************************************************
# This message was sent to pazoulai@gmail.com. If you don't want to receive these emails from this company in the future, please go to:
#
# /n &#169; Amazon; P.O. Box 80683; Seattle, WA 98108-1226; USA/n
#
#
#
# #######################################################
#
#
#
#  Dear Paul,
#
# Thank you very much for your application to Amazon.
#
# As a next step, you will be invited to complete an online test. The test will be sent to you via email within the next 24-48 hours. Detailed instructions will be provided in the email, along with the testing link.
#
# Whilst the test should be completed within 14 working days of being received (after which the link will expire), we hire on a rolling basis and have limited interview spots so would encourage you to complete as soon as possible. We are unable to grant extensions beyond this point.
#
# If you haven’t received the test link email within the next few days then please check your spam/junk email folder, as sometimes these emails can be misdirected.
#
# If you have a disability that you believe may affect your ability to participate in the assessment then please send an email to sp-emea@amazon.comwith the name of the country where you have applied to in the subject line of the email and we will connect with you to discuss your concerns and possible support options.
#
# Good luck!
#
# Kind Regards,
# Student Programs Recruitment Team
#
# (Please do not reply to this email - we are unable to review and respond to messages at this address.)
#
# Amazon is an equal opportunities employer. We believe passionately that employing a diverse workforce is central to our success. We make recruiting decisions based on your experience and skills. We value your passion to discover, invent, simplify and build.
# Protecting your privacy and the security of your data is a longstanding top priority for Amazon. Please consult our Privacy Notice to know more about how we collect, use and transfer the personal data of our candidates.
#
#
# **************************************************
# This message was sent to pazoulai@gmail.com. If you don't want to receive these emails from this company in the future, please go to:
#
# /n &#169; Amazon; P.O. Box 80683; Seattle, WA 98108-1226; USA/n
#
#
#
# #######################################################
#
#
#
#
#
#
#
# #######################################################
